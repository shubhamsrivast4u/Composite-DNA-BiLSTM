# %%
# In[1]:


# # Composite DNA Decoder: Training & Evaluation - Eta-Based Variable Ratio
# ## Cross-Platform Robustness Study: Nanopore (R21, B22, NP22, NPF22) + Newer Illumina (BOS22)
# ## Each profile uses its standard sequence length from the corresponding original dataset

# =============================================================================
# CELL 1: DEVICE CONFIGURATION
# =============================================================================
import os
import torch

DEVICE_ID = "2"
os.environ["CUDA_VISIBLE_DEVICES"] = DEVICE_ID


# In[2]:

# =============================================================================
# CELL 2: IMPORTS
# =============================================================================
import random
import pickle
import json
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import time
from datetime import datetime

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torch.optim.lr_scheduler import CosineAnnealingLR, LinearLR, SequentialLR

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"✅ Using device: {device}")
if torch.cuda.is_available():
    print(f"   GPU: {torch.cuda.get_device_name(0)}")
# Out:
# ✅ Using device: cuda
#    GPU: NVIDIA GeForce RTX 3080

# %%
# In[3]:

# =============================================================================
# CELL 3: CONFIGURATION & HYPERPARAMETERS
# =============================================================================

# ------------------- SELECT ERROR MODEL -------------------
# NEW PLATFORM OPTIONS (cross-platform robustness study):
#   "R21"    -> Oxford Nanopore MinION + Twist (Rang et al. 2021)
#   "B22"    -> Nanopore MinION Short + Twist  (Bar-Lev et al. 2022)
#   "BOS22"  -> Illumina MiSeq 2022 + Twist   (very low error, newer Illumina)
#   "NP22"   -> Nanopore Pilot Nov-2022 + Twist (highly non-uniform across bases)
#   "NPF22"  -> Nanopore Full Pool Nov-2022 + Twist (comprehensive Nanopore)
# ----------------------------------------------------------
ERROR_MODEL = "B22"  # <-- CHANGE THIS

# ------------------- ETA-BASED ALPHABET PARAMETERS -------------------
ETA = 0.2
ELL_VALUES = [-2, -1, 0, 1, 2]

# Dataset parameters
NUM_SAMPLES = 100000
MAX_COVERAGE = 50

# Calculate vocab size
NUM_PURE_BASES = 4
NUM_TWO_MIX_PAIRS = 6
VOCAB_SIZE = NUM_PURE_BASES + NUM_TWO_MIX_PAIRS * len(ELL_VALUES)  # 34

# Error model specifications - standard sequence lengths from original datasets
# All new profiles use the same Erlich/Twist 152nt oligo pool (16nt index → n=136)
# Combined with original profiles (EZ17 n=136, G15 n=104, O17 n=77), this gives
# standard sequence lengths n ∈ {77, 104, 136} across the full set of 8 profiles.
ERROR_MODEL_SPECS = {
    "R21": {
        "full_length": 152,
        "index_length": 16,
        "seq_length": 136,  # 152 - 16 (same Erlich/Twist pool)
        "name": "R21",
        "platform": "Oxford Nanopore MinION",
        "synthesis": "Twist Bioscience"
    },
    "B22": {
        "full_length": 152,
        "index_length": 16,
        "seq_length": 136,  # 152 - 16 (same Erlich/Twist pool)
        "name": "B22",
        "platform": "Nanopore MinION Short",
        "synthesis": "Twist Bioscience"
    },
    "BOS22": {
        "full_length": 152,
        "index_length": 16,
        "seq_length": 136,  # 152 - 16 (same Erlich/Twist pool)
        "name": "BOS22",
        "platform": "Illumina MiSeq 2022",
        "synthesis": "Twist Bioscience"
    },
    "NP22": {
        "full_length": 152,
        "index_length": 16,
        "seq_length": 136,  # 152 - 16 (same Erlich/Twist pool)
        "name": "NP22",
        "platform": "Nanopore Pilot Nov-2022",
        "synthesis": "Twist Bioscience"
    },
    "NPF22": {
        "full_length": 152,
        "index_length": 16,
        "seq_length": 136,  # 152 - 16 (same Erlich/Twist pool)
        "name": "NPF22",
        "platform": "Nanopore Full Pool Nov-2022",
        "synthesis": "Twist Bioscience"
    },
}

# Build configuration
CONFIG = {
    # Error Model
    "error_model": ERROR_MODEL,
    "error_name": ERROR_MODEL_SPECS[ERROR_MODEL]["name"],
    "platform": ERROR_MODEL_SPECS[ERROR_MODEL]["platform"],
    
    # Eta Parameters
    "eta": ETA,
    "ell_values": ELL_VALUES,
    "alphabet_mode": f"eta{ETA}",
    
    # Data Paths (matches dataset_generator_eta_cross_platform.py output)
    "dataset_dir": "./dataset_cross_platform",
    "dataset_name": f"dna_{ERROR_MODEL_SPECS[ERROR_MODEL]['name']}_eta{ETA}",
    
    # Results directory
    "results_dir": f"./results_crossplatform_{ERROR_MODEL_SPECS[ERROR_MODEL]['name']}_eta{ETA}",
    
    # Vocabulary
    "vocab_size": VOCAB_SIZE,
    
    # Sequence Parameters
    "seq_length": ERROR_MODEL_SPECS[ERROR_MODEL]["seq_length"],
    
    # Experiment Parameters
    "coverage_levels": [1, 2, 3, 5, 8, 10, 15, 20, 25, 30, 40, 50],
    
    # Model Architecture (same as original for fair comparison)
    "input_channels": 4,
    "hidden_dim": 128,
    "num_layers": 2,
    "dropout": 0.2,
    "bidirectional": True,
    
    # Training Parameters
    "batch_size": 500,
    "learning_rate": 1e-3,
    "weight_decay": 1e-4,
    "epochs": 100,
    "patience": 10,
    "warmup_epochs": 10,
    "min_lr": 1e-6,
    
    # Reproducibility
    "seed": 42
}

# Complete dataset path
CONFIG["dataset_path"] = (f"{CONFIG['dataset_dir']}/"
                          f"{CONFIG['dataset_name']}_"
                          f"{NUM_SAMPLES}_{MAX_COVERAGE}.pkl")

# Create results directory
os.makedirs(CONFIG['results_dir'], exist_ok=True)

print(f"{'='*70}")
print(f"📋 CROSS-PLATFORM ETA-BASED CONFIGURATION")
print(f"{'='*70}")
print(f"   Error Model: {CONFIG['error_model']} ({CONFIG['error_name']})")
print(f"   Platform: {CONFIG['platform']}")
print(f"   Oligo: {ERROR_MODEL_SPECS[ERROR_MODEL]['full_length']}nt − "
      f"{ERROR_MODEL_SPECS[ERROR_MODEL]['index_length']}nt = "
      f"{CONFIG['seq_length']}nt (standard)")
print(f"   Eta: {CONFIG['eta']}, Ell Values: {CONFIG['ell_values']}")
print(f"   Sequence Length: {CONFIG['seq_length']}")
print(f"   Vocab Size: {CONFIG['vocab_size']} classes")
print(f"   Theoretical Capacity: {np.log2(CONFIG['vocab_size']):.4f} bits/position")
print(f"   Dataset Path: {CONFIG['dataset_path']}")
print(f"   Results Dir: {CONFIG['results_dir']}")
print(f"{'='*70}")
# Out:
# ======================================================================
# 📋 CROSS-PLATFORM ETA-BASED CONFIGURATION
# ======================================================================
#    Error Model: B22 (B22)
#    Platform: Nanopore MinION Short
#    Oligo: 152nt − 16nt = 136nt (standard)
#    Eta: 0.2, Ell Values: [-2, -1, 0, 1, 2]
#    Sequence Length: 136
#    Vocab Size: 34 classes
#    Theoretical Capacity: 5.0875 bits/position
#    Dataset Path: ./dataset_cross_platform/dna_B22_eta0.2_100000_50.pkl
#    Results Dir: ./results_crossplatform_B22_eta0.2
# ======================================================================

# %%
# In[4]:

# =============================================================================
# CELL 4: SEED & REPRODUCIBILITY
# =============================================================================
def set_seed(seed):
    """Set seed for reproducibility across all libraries."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

set_seed(CONFIG['seed'])
print(f"🎲 Random seed set to: {CONFIG['seed']}")
# Out:
# 🎲 Random seed set to: 42

# %%
# In[5]:

# =============================================================================
# CELL 5: BUILD ETA-BASED ALPHABET MAPPINGS
# =============================================================================
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# SAME AS: train_evaluate_eta_based-Erlich.py → Cell 5
# Copy: build_eta_based_symbol_to_idx(), build_eta_based_ideal_vectors()
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

def build_eta_based_symbol_to_idx(eta, ell_values):
    """Build symbol-to-index mapping for eta-based alphabet."""
    symbol_to_idx = {'A': 0, 'C': 1, 'G': 2, 'T': 3}
    
    pair_names = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6']
    current_idx = 4
    
    for pair_name in pair_names:
        for ell in ell_values:
            if ell >= 0:
                symbol_name = f"{pair_name}_ell{ell}"
            else:
                symbol_name = f"{pair_name}_ell_neg{abs(ell)}"
            symbol_to_idx[symbol_name] = current_idx
            current_idx += 1
    
    return symbol_to_idx


def build_eta_based_ideal_vectors(eta, ell_values):
    """
    Build ideal frequency vectors for eta-based alphabet.
    Returns: torch.Tensor of shape (vocab_size, 4)
    """
    ideal_vectors = [
        [1.0, 0.0, 0.0, 0.0],  # A
        [0.0, 1.0, 0.0, 0.0],  # C
        [0.0, 0.0, 1.0, 0.0],  # G
        [0.0, 0.0, 0.0, 1.0],  # T
    ]
    
    # Two-mix pairs: (vec_idx1, vec_idx2)
    pair_indices = [
        (0, 1),  # B1: A|C
        (0, 2),  # B2: A|G
        (0, 3),  # B3: A|T
        (1, 2),  # B4: C|G
        (1, 3),  # B5: C|T
        (2, 3),  # B6: G|T
    ]
    
    for idx1, idx2 in pair_indices:
        for ell in ell_values:
            prob1 = 0.5 + ell * eta
            prob2 = 0.5 - ell * eta
            
            vec = [0.0, 0.0, 0.0, 0.0]
            vec[idx1] = prob1
            vec[idx2] = prob2
            ideal_vectors.append(vec)
    
    return torch.tensor(ideal_vectors, dtype=torch.float32)


# Build mappings
SYMBOL_TO_IDX = build_eta_based_symbol_to_idx(CONFIG["eta"], CONFIG["ell_values"])
IDX_TO_SYMBOL = {v: k for k, v in SYMBOL_TO_IDX.items()}
IDEAL_VECTORS = build_eta_based_ideal_vectors(CONFIG["eta"], CONFIG["ell_values"]).to(device)

print(f"\n📊 Symbol Mappings (η={CONFIG['eta']}):")
print(f"   Total symbols: {len(SYMBOL_TO_IDX)}")
print(f"\n   Sample mappings (first 10):")
for i, (sym, idx) in enumerate(sorted(SYMBOL_TO_IDX.items(), key=lambda x: x[1])[:10]):
    vec = IDEAL_VECTORS[idx].cpu().numpy()
    print(f"   {sym:<16} {idx:<4} [{vec[0]:.2f}, {vec[1]:.2f}, {vec[2]:.2f}, {vec[3]:.2f}]")
print(f"   ... ({len(SYMBOL_TO_IDX) - 10} more)")
# Out:
# 📊 Symbol Mappings (η=0.2):
#    Total symbols: 34
#
#    Sample mappings (first 10):
#    A                0    [1.00, 0.00, 0.00, 0.00]
#    C                1    [0.00, 1.00, 0.00, 0.00]
#    G                2    [0.00, 0.00, 1.00, 0.00]
#    T                3    [0.00, 0.00, 0.00, 1.00]
#    B1_ell_neg2      4    [0.10, 0.90, 0.00, 0.00]
#    B1_ell_neg1      5    [0.30, 0.70, 0.00, 0.00]
#    B1_ell0          6    [0.50, 0.50, 0.00, 0.00]
#    B1_ell1          7    [0.70, 0.30, 0.00, 0.00]
#    B1_ell2          8    [0.90, 0.10, 0.00, 0.00]
#    B2_ell_neg2      9    [0.10, 0.00, 0.90, 0.00]
#    ... (24 more)

# %%
# In[6]:

# =============================================================================
# CELL 6: DATA PREPROCESSING
# =============================================================================
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# SAME AS: train_evaluate_eta_based-Erlich.py → Cell 6
# Copy: preprocess_cluster_to_matrix()
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

def preprocess_cluster_to_matrix(cluster_reads, target_length):
    """
    Convert variable-length noisy reads into a (4, target_length) normalized frequency matrix.
    """
    profile_matrix = np.zeros((4, target_length), dtype=np.float32)
    base_map = {'A': 0, 'C': 1, 'G': 2, 'T': 3}
    num_reads = len(cluster_reads)
    
    for read in cluster_reads:
        read_len = len(read)
        if read_len == 0:
            continue
            
        for t_idx in range(target_length):
            read_idx = int((t_idx + 0.5) * (read_len / target_length))
            if read_idx >= read_len:
                read_idx = read_len - 1
            
            base = read[read_idx]
            if base in base_map:
                row_idx = base_map[base]
                profile_matrix[row_idx, t_idx] += 1.0
                
    if num_reads > 0:
        profile_matrix /= num_reads
        
    return profile_matrix

# %%
# In[7]:

# =============================================================================
# CELL 7: PYTORCH DATASET CLASS
# =============================================================================
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# SAME AS: train_evaluate_eta_based-Erlich.py → Cell 7
# Copy: CompositeDNADatasetEta class
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

class CompositeDNADatasetEta(Dataset):
    """PyTorch Dataset for Eta-Based Composite DNA data."""
    
    def __init__(self, data_path, seq_length, symbol_to_idx, limit_coverage=None):
        with open(data_path, 'rb') as f:
            raw_data = pickle.load(f)
        self.samples = raw_data['data']
        self.metadata = raw_data['metadata']
        self.seq_length = seq_length
        self.symbol_to_idx = symbol_to_idx
        self.limit_coverage = limit_coverage
        
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        item = self.samples[idx]
        cluster = item['cluster']
        
        if self.limit_coverage is not None:
            actual_limit = min(self.limit_coverage, len(cluster))
            cluster = cluster[:actual_limit]
            
        x_data = preprocess_cluster_to_matrix(cluster, self.seq_length)
        label_seq = item['label']
        y_data = np.array([self.symbol_to_idx[s] for s in label_seq], dtype=np.longlong)
        
        return torch.tensor(x_data, dtype=torch.float32), torch.tensor(y_data, dtype=torch.long)

# %%
# In[8]:

# =============================================================================
# CELL 8: NEURAL NETWORK MODEL
# =============================================================================
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# SAME AS: train_evaluate_eta_based-Erlich.py → Cell 8
# Copy: CompositeDecoderLSTM class
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

class CompositeDecoderLSTM(nn.Module):
    """Bidirectional LSTM Decoder for Composite DNA."""
    
    def __init__(self, config):
        super(CompositeDecoderLSTM, self).__init__()
        
        self.lstm = nn.LSTM(
            input_size=config['input_channels'],
            hidden_size=config['hidden_dim'],
            num_layers=config['num_layers'],
            batch_first=True,
            bidirectional=config['bidirectional'],
            dropout=config['dropout'] if config['num_layers'] > 1 else 0
        )
        
        fc_in = config['hidden_dim'] * 2 if config['bidirectional'] else config['hidden_dim']
        self.fc = nn.Linear(fc_in, config['vocab_size'])
        
    def forward(self, x):
        # x: (Batch, 4, L) -> (Batch, L, 4)
        x = x.permute(0, 2, 1)
        out, _ = self.lstm(x)
        logits = self.fc(out)
        # Return: (Batch, vocab_size, L)
        return logits.permute(0, 2, 1)

# %%
# In[9]:

# =============================================================================
# CELL 9: BASELINE DECODERS
# =============================================================================
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# SAME AS: train_evaluate_eta_based-Erlich.py → Cell 9
# Copy: min_distance_decoder(), kl_divergence_decoder(), maximum_likelihood_decoder()
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

def min_distance_decoder(obs, ideal_vectors):
    """Minimum Euclidean Distance Decoder (L2 norm)."""
    dists = torch.sum((obs.unsqueeze(2) - ideal_vectors.unsqueeze(0).unsqueeze(0)) ** 2, dim=3)
    return torch.argmin(dists, dim=2)


def kl_divergence_decoder(obs, ideal_vectors, epsilon=0.01):
    """KL Divergence Decoder."""
    ideal_safe = ideal_vectors.clone()
    ideal_safe = torch.clamp(ideal_safe, min=epsilon)
    ideal_safe = ideal_safe / ideal_safe.sum(dim=-1, keepdim=True)
    
    obs_expanded = obs.unsqueeze(2)
    log_ideal = torch.log(ideal_safe).unsqueeze(0).unsqueeze(0)
    
    cross_entropy = -(obs_expanded * log_ideal).sum(dim=-1)
    return torch.argmin(cross_entropy, dim=-1)


def maximum_likelihood_decoder(obs, ideal_vectors, epsilon=0.01):
    """Maximum Likelihood Decoder."""
    ideal_safe = ideal_vectors.clone()
    ideal_safe = torch.clamp(ideal_safe, min=epsilon)
    ideal_safe = ideal_safe / ideal_safe.sum(dim=-1, keepdim=True)
    
    obs_expanded = obs.unsqueeze(2)
    log_ideal = torch.log(ideal_safe).unsqueeze(0).unsqueeze(0)
    
    log_likelihood = (obs_expanded * log_ideal).sum(dim=-1)
    return torch.argmax(log_likelihood, dim=-1)

# %%
# In[10]:

# =============================================================================
# CELL 10: EARLY STOPPING CLASS
# =============================================================================
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# SAME AS: train_evaluate_eta_based-Erlich.py → Cell 10
# Copy: EarlyStopping class
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

class EarlyStopping:
    """Early stopping with patience and best model saving."""
    
    def __init__(self, patience=5, path='checkpoint.pt', verbose=True):
        self.patience = patience
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.path = path
        self.verbose = verbose
        self.best_val_loss = float('inf')

    def __call__(self, val_loss, model):
        score = -val_loss
        
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score:
            self.counter += 1
            if self.verbose:
                print(f"      EarlyStopping counter: {self.counter}/{self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0
            
    def save_checkpoint(self, val_loss, model):
        if self.verbose:
            print(f"      ✓ Val loss improved ({self.best_val_loss:.4f} → {val_loss:.4f}). Saving...")
        torch.save(model.state_dict(), self.path)
        self.best_val_loss = val_loss

# %%
# In[11]:

# =============================================================================
# CELL 11: TRAINING FUNCTION
# =============================================================================
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# SAME AS: train_evaluate_eta_based-Erlich.py → Cell 11
# Copy: train_model() function
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

def train_model(model, train_loader, val_loader, config, weights_path, device):
    """Train the model with warmup + cosine annealing scheduler."""
    
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(
        model.parameters(), 
        lr=config['learning_rate'],
        weight_decay=config['weight_decay']
    )
    
    warmup_scheduler = LinearLR(optimizer, start_factor=0.1, total_iters=config['warmup_epochs'])
    cosine_scheduler = CosineAnnealingLR(
        optimizer, T_max=config['epochs'] - config['warmup_epochs'], eta_min=config['min_lr']
    )
    scheduler = SequentialLR(
        optimizer, schedulers=[warmup_scheduler, cosine_scheduler], milestones=[config['warmup_epochs']]
    )
    
    early_stopper = EarlyStopping(patience=config['patience'], path=weights_path, verbose=True)
    
    history = {'train_loss': [], 'val_loss': [], 'lr': []}
    
    print(f"\n   🏋️ Training Configuration:")
    print(f"      Epochs: {config['epochs']}, Patience: {config['patience']}")
    print(f"      Warmup: {config['warmup_epochs']} epochs")
    print(f"      LR: {config['learning_rate']} → {config['min_lr']}")
    
    for epoch in range(config['epochs']):
        start_time = time.time()
        
        # Training
        model.train()
        train_loss_accum = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            train_loss_accum += loss.item()
        avg_train_loss = train_loss_accum / len(train_loader)
        
        # Validation
        model.eval()
        val_loss_accum = 0.0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                val_loss_accum += criterion(outputs, labels).item()
        avg_val_loss = val_loss_accum / len(val_loader)
        
        current_lr = optimizer.param_groups[0]['lr']
        history['train_loss'].append(avg_train_loss)
        history['val_loss'].append(avg_val_loss)
        history['lr'].append(current_lr)
        
        elapsed = time.time() - start_time
        print(f"   Epoch {epoch+1:03d}/{config['epochs']} | "
              f"Train: {avg_train_loss:.4f} | Val: {avg_val_loss:.4f} | "
              f"LR: {current_lr:.2e} | Time: {elapsed:.1f}s")
        
        scheduler.step()
        early_stopper(avg_val_loss, model)
        
        if early_stopper.early_stop:
            print(f"\n   🛑 Early stopping triggered at epoch {epoch+1}")
            break
    
    return history

# %%
# In[12]:

# =============================================================================
# CELL 12: EVALUATION FUNCTION
# =============================================================================
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# SAME AS: train_evaluate_eta_based-Erlich.py → Cell 12
# Copy: evaluate_all_decoders() function
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

def evaluate_all_decoders(model, loader, ideal_vectors, device):
    """Evaluate all 4 decoders on the given data loader."""
    model.eval()
    
    correct = {'lstm': 0, 'mindist': 0, 'kl': 0, 'ml': 0}
    total = 0
    
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            obs = inputs.permute(0, 2, 1)
            
            outputs = model(inputs)
            pred_lstm = torch.argmax(outputs, dim=1)
            pred_mindist = min_distance_decoder(obs, ideal_vectors)
            pred_kl = kl_divergence_decoder(obs, ideal_vectors)
            pred_ml = maximum_likelihood_decoder(obs, ideal_vectors)
            
            total += labels.numel()
            correct['lstm'] += (pred_lstm == labels).sum().item()
            correct['mindist'] += (pred_mindist == labels).sum().item()
            correct['kl'] += (pred_kl == labels).sum().item()
            correct['ml'] += (pred_ml == labels).sum().item()
    
    accuracies = {k: 100 * v / total for k, v in correct.items()}
    return accuracies

# %%
# In[13]:

# =============================================================================
# CELL 13: FULL EXPERIMENT FOR SINGLE COVERAGE
# =============================================================================

def run_experiment_for_coverage(coverage_M, config, symbol_to_idx, ideal_vectors, device):
    """Run complete experiment for a single coverage level."""
    
    print(f"\n{'='*70}")
    print(f"🔬 EXPERIMENT FOR COVERAGE M = {coverage_M}")
    print(f"   Error Model: {config['error_name']} ({config['platform']})")
    print(f"   Eta: {config['eta']}, Vocab Size: {config['vocab_size']}")
    print(f"   Seq Length: {config['seq_length']}")
    print(f"{'='*70}")
    
    set_seed(config['seed'])
    
    full_ds = CompositeDNADatasetEta(
        config['dataset_path'], config['seq_length'], symbol_to_idx, limit_coverage=coverage_M
    )
    
    train_size = int(0.8 * len(full_ds))
    val_size = len(full_ds) - train_size
    train_ds, val_ds = random_split(full_ds, [train_size, val_size])
    
    train_loader = DataLoader(train_ds, batch_size=config['batch_size'], shuffle=True, num_workers=0)
    val_loader = DataLoader(val_ds, batch_size=config['batch_size'], shuffle=False, num_workers=0)
    
    print(f"   📊 Data: {train_size:,} train | {val_size:,} validation")
    
    model = CompositeDecoderLSTM(config).to(device)
    num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"   🧠 Model: {config['vocab_size']} classes, {num_params:,} parameters")
    
    model_prefix = f"{config['error_name']}_eta{config['eta']}"
    best_weights_path = os.path.join(config['results_dir'], f"best_model_{model_prefix}_M{coverage_M}.pth")
    final_weights_path = os.path.join(config['results_dir'], f"final_model_{model_prefix}_M{coverage_M}.pth")
    history_path = os.path.join(config['results_dir'], f"training_history_{model_prefix}_M{coverage_M}.json")
    
    history = train_model(model, train_loader, val_loader, config, best_weights_path, device)
    
    torch.save(model.state_dict(), final_weights_path)
    print(f"   💾 Final model saved: {final_weights_path}")
    
    with open(history_path, 'w') as f:
        json.dump(history, f, indent=4)
    
    print(f"\n   📈 Evaluating all decoders...")
    model.load_state_dict(torch.load(best_weights_path, map_location=device))
    
    accuracies = evaluate_all_decoders(model, val_loader, ideal_vectors, device)
    
    print(f"\n   ✅ RESULTS M={coverage_M} ({config['error_name']}, η={config['eta']}):")
    print(f"      Bi-LSTM:         {accuracies['lstm']:.2f}%")
    print(f"      Min. Distance:   {accuracies['mindist']:.2f}%")
    print(f"      KL Divergence:   {accuracies['kl']:.2f}%")
    print(f"      Max. Likelihood: {accuracies['ml']:.2f}%")
    
    return accuracies, history

# %%
# In[14]:

# =============================================================================
# CELL 14: PLOTTING FUNCTIONS
# =============================================================================
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# SAME AS: train_evaluate_eta_based-Erlich.py → Cell 14
# Copy: plot_training_history(), plot_comparison_results()
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

def plot_training_history(history, coverage_M, save_path, config):
    """Plot training and validation loss curves."""
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    
    epochs = range(1, len(history['train_loss']) + 1)
    
    ax1.plot(epochs, history['train_loss'], 'b-', linewidth=2, label='Train Loss')
    ax1.plot(epochs, history['val_loss'], 'r-', linewidth=2, label='Val Loss')
    ax1.set_xlabel('Epoch', fontsize=12)
    ax1.set_ylabel('Loss', fontsize=12)
    ax1.set_title(f'Training & Validation Loss (M={coverage_M}, η={config["eta"]})\n'
                  f'{config["error_name"]} ({config["platform"]})', fontsize=13)
    ax1.legend(fontsize=11)
    ax1.grid(True, alpha=0.3)
    
    ax2.plot(epochs, history['lr'], 'g-', linewidth=2)
    ax2.set_xlabel('Epoch', fontsize=12)
    ax2.set_ylabel('Learning Rate', fontsize=12)
    ax2.set_title(f'Learning Rate Schedule (M={coverage_M})', fontsize=14)
    ax2.set_yscale('log')
    ax2.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.close()
    print(f"   📈 Training plot saved: {save_path}")


def plot_comparison_results(results, save_path, config):
    """Plot comparison of all decoders across coverage levels."""
    plt.figure(figsize=(12, 7))
    
    plt.plot(results['coverage'], results['lstm'], 
             'o-', lw=2.5, ms=8, c='#2ecc71', label='Bi-LSTM (Ours)')
    plt.plot(results['coverage'], results['mindist'], 
             's--', lw=2.5, ms=8, c='#e74c3c', label='Min. Distance')
    plt.plot(results['coverage'], results['kl'], 
             '^-.', lw=2.5, ms=8, c='#3498db', label='KL Divergence')
    plt.plot(results['coverage'], results['ml'], 
             'd:', lw=2.5, ms=8, c='#9b59b6', label='Max. Likelihood')
    
    title = (f"Composite DNA Decoding: η={config['eta']} ({config['vocab_size']} classes)\n"
             f"Error Model: {config['error_name']} ({config['platform']}), "
             f"Seq Length: {config['seq_length']}")
    
    plt.xlabel("Coverage Depth (M)", fontsize=12)
    plt.ylabel("Symbol Accuracy (%)", fontsize=12)
    plt.title(title, fontsize=14)
    plt.legend(fontsize=11, loc='lower right')
    plt.grid(True, alpha=0.3)
    plt.ylim(0, 105)
    plt.xticks(results['coverage'])
    
    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.close()
    print(f"📈 Comparison plot saved: {save_path}")

# %%
# In[15]:

# =============================================================================
# CELL 15: VERIFY DATASET EXISTS
# =============================================================================

print("\n" + "="*70)
print("📦 LOADING DATASET")
print("="*70)

if not os.path.exists(CONFIG['dataset_path']):
    raise FileNotFoundError(
        f"\n❌ Dataset not found: {CONFIG['dataset_path']}\n"
        f"   Please run dataset_generator_eta_cross_platform.py first with:\n"
        f"   ERROR_MODEL = \"{CONFIG['error_model']}\"\n"
        f"   ETA = {CONFIG['eta']}, ELL_VALUES = {CONFIG['ell_values']}"
    )

with open(CONFIG['dataset_path'], 'rb') as f:
    data = pickle.load(f)

print(f"✅ Dataset loaded: {CONFIG['dataset_path']}")
print(f"   Samples: {len(data['data']):,}")
print(f"   Vocab Size: {data['metadata']['vocab_size']}")
print(f"   Eta: {data['metadata']['eta']}")
print(f"   Sequence Length: {data['metadata']['seq_length']}")
if 'platform' in data['metadata']:
    print(f"   Platform: {data['metadata']['platform']}")
# Out:
# ======================================================================
# 📦 LOADING DATASET
# ======================================================================
# ✅ Dataset loaded: ./dataset_cross_platform/dna_B22_eta0.2_100000_50.pkl
#    Samples: 100,000
#    Vocab Size: 34
#    Eta: 0.2
#    Sequence Length: 136
#    Platform: Nanopore MinION Short

# %%
# In[16]:

# =============================================================================
# CELL 16: MAIN EXECUTION - RUN ALL EXPERIMENTS
# =============================================================================

print("\n" + "="*70)
print("🚀 RUNNING EXPERIMENTS FOR ALL COVERAGE LEVELS")
print("="*70)
print(f"   Error Model: {CONFIG['error_name']} ({CONFIG['platform']})")
print(f"   Eta: {CONFIG['eta']}, Vocab Size: {CONFIG['vocab_size']}")
print(f"   Seq Length: {CONFIG['seq_length']}")
print(f"   Coverage Levels: {CONFIG['coverage_levels']}")

results = {
    'coverage': CONFIG['coverage_levels'],
    'lstm': [],
    'mindist': [],
    'kl': [],
    'ml': [],
    'config': {
        'error_model': CONFIG['error_model'],
        'error_name': CONFIG['error_name'],
        'platform': CONFIG['platform'],
        'seq_length': CONFIG['seq_length'],
        'eta': CONFIG['eta'],
        'ell_values': CONFIG['ell_values'],
        'vocab_size': CONFIG['vocab_size'],
        'hidden_dim': CONFIG['hidden_dim'],
        'num_layers': CONFIG['num_layers'],
        'timestamp': datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    }
}

all_histories = {}

for M in CONFIG['coverage_levels']:
    accuracies, history = run_experiment_for_coverage(
        M, CONFIG, SYMBOL_TO_IDX, IDEAL_VECTORS, device
    )
    
    results['lstm'].append(accuracies['lstm'])
    results['mindist'].append(accuracies['mindist'])
    results['kl'].append(accuracies['kl'])
    results['ml'].append(accuracies['ml'])
    all_histories[M] = history
    
    plot_prefix = f"{CONFIG['error_name']}_eta{CONFIG['eta']}"
    plot_path = os.path.join(CONFIG['results_dir'], f"training_plot_{plot_prefix}_M{M}.png")
    plot_training_history(history, M, plot_path, CONFIG)
# Out:
# ======================================================================
# 🚀 RUNNING EXPERIMENTS FOR ALL COVERAGE LEVELS
# ======================================================================
#    Error Model: B22 (Nanopore MinION Short)
#    Eta: 0.2, Vocab Size: 34
#    Seq Length: 136
#    Coverage Levels: [1, 2, 3, 5, 8, 10, 15, 20, 25, 30, 40, 50]
#
# ======================================================================
# 🔬 EXPERIMENT FOR COVERAGE M = 1
#    Error Model: B22 (Nanopore MinION Short)
#    Eta: 0.2, Vocab Size: 34
#    Seq Length: 136
# ======================================================================
#    📊 Data: 80,000 train | 20,000 validation
#    🧠 Model: 34 classes, 541,218 parameters
#
#    🏋️ Training Configuration:
#       Epochs: 100, Patience: 10
#       Warmup: 10 epochs
#       LR: 0.001 → 1e-06
#    Epoch 001/100 | Train: 3.4829 | Val: 3.3612 | LR: 1.00e-04 | Time: 39.8s
#       ✓ Val loss improved (inf → 3.3612). Saving...
#    Epoch 002/100 | Train: 3.2174 | Val: 3.1645 | LR: 1.90e-04 | Time: 39.5s
#       ✓ Val loss improved (3.3612 → 3.1645). Saving...
#    Epoch 003/100 | Train: 3.1608 | Val: 3.1473 | LR: 2.80e-04 | Time: 41.4s
#       ✓ Val loss improved (3.1645 → 3.1473). Saving...
#    Epoch 004/100 | Train: 3.1377 | Val: 3.1221 | LR: 3.70e-04 | Time: 38.3s
#       ✓ Val loss improved (3.1473 → 3.1221). Saving...
#    Epoch 005/100 | Train: 3.1211 | Val: 3.1136 | LR: 4.60e-04 | Time: 38.3s
#       ✓ Val loss improved (3.1221 → 3.1136). Saving...
#    Epoch 006/100 | Train: 3.1150 | Val: 3.1103 | LR: 5.50e-04 | Time: 37.8s
#       ✓ Val loss improved (3.1136 → 3.1103). Saving...
#    Epoch 007/100 | Train: 3.1117 | Val: 3.1090 | LR: 6.40e-04 | Time: 39.7s
#       ✓ Val loss improved (3.1103 → 3.1090). Saving...
#    Epoch 008/100 | Train: 3.1100 | Val: 3.1074 | LR: 7.30e-04 | Time: 40.2s
#       ✓ Val loss improved (3.1090 → 3.1074). Saving...
#    Epoch 009/100 | Train: 3.1086 | Val: 3.1086 | LR: 8.20e-04 | Time: 38.2s
#       EarlyStopping counter: 1/10
#    Epoch 010/100 | Train: 3.1074 | Val: 3.1068 | LR: 9.10e-04 | Time: 38.9s
#       ✓ Val loss improved (3.1074 → 3.1068). Saving...
# /homes/shubham/anaconda3/envs/pytorchenv/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:149: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
#    Epoch 011/100 | Train: 3.1070 | Val: 3.1053 | LR: 1.00e-03 | Time: 37.8s
#       ✓ Val loss improved (3.1068 → 3.1053). Saving...
#    Epoch 012/100 | Train: 3.1063 | Val: 3.1058 | LR: 1.00e-03 | Time: 40.4s
#       EarlyStopping counter: 1/10
#    Epoch 013/100 | Train: 3.1056 | Val: 3.1047 | LR: 9.99e-04 | Time: 39.2s
#       ✓ Val loss improved (3.1053 → 3.1047). Saving...
#    Epoch 014/100 | Train: 3.1053 | Val: 3.1057 | LR: 9.97e-04 | Time: 38.6s
#       EarlyStopping counter: 1/10
#    Epoch 015/100 | Train: 3.1051 | Val: 3.1045 | LR: 9.95e-04 | Time: 38.9s
#       ✓ Val loss improved (3.1047 → 3.1045). Saving...
#    Epoch 016/100 | Train: 3.1047 | Val: 3.1046 | LR: 9.92e-04 | Time: 39.7s
#       EarlyStopping counter: 1/10
#    Epoch 017/100 | Train: 3.1047 | Val: 3.1044 | LR: 9.89e-04 | Time: 38.4s
#       ✓ Val loss improved (3.1045 → 3.1044). Saving...
#    Epoch 018/100 | Train: 3.1046 | Val: 3.1042 | LR: 9.85e-04 | Time: 40.1s
#       ✓ Val loss improved (3.1044 → 3.1042). Saving...
#    Epoch 019/100 | Train: 3.1042 | Val: 3.1042 | LR: 9.81e-04 | Time: 38.5s
#       EarlyStopping counter: 1/10
#    Epoch 020/100 | Train: 3.1041 | Val: 3.1039 | LR: 9.76e-04 | Time: 38.8s
#       ✓ Val loss improved (3.1042 → 3.1039). Saving...
#    Epoch 021/100 | Train: 3.1040 | Val: 3.1039 | LR: 9.70e-04 | Time: 38.4s
#       ✓ Val loss improved (3.1039 → 3.1039). Saving...
#    Epoch 022/100 | Train: 3.1037 | Val: 3.1040 | LR: 9.64e-04 | Time: 40.5s
#       EarlyStopping counter: 1/10
#    Epoch 023/100 | Train: 3.1037 | Val: 3.1044 | LR: 9.57e-04 | Time: 37.9s
#       EarlyStopping counter: 2/10
#    Epoch 024/100 | Train: 3.1035 | Val: 3.1046 | LR: 9.49e-04 | Time: 39.0s
#       EarlyStopping counter: 3/10
#    Epoch 025/100 | Train: 3.1035 | Val: 3.1038 | LR: 9.42e-04 | Time: 38.2s
#       ✓ Val loss improved (3.1039 → 3.1038). Saving...
#    Epoch 026/100 | Train: 3.1033 | Val: 3.1040 | LR: 9.33e-04 | Time: 39.2s
#       EarlyStopping counter: 1/10
#    Epoch 027/100 | Train: 3.1033 | Val: 3.1042 | LR: 9.24e-04 | Time: 38.4s
#       EarlyStopping counter: 2/10
#    Epoch 028/100 | Train: 3.1032 | Val: 3.1037 | LR: 9.15e-04 | Time: 38.6s
#       ✓ Val loss improved (3.1038 → 3.1037). Saving...
#    Epoch 029/100 | Train: 3.1032 | Val: 3.1040 | LR: 9.05e-04 | Time: 38.6s
#       EarlyStopping counter: 1/10
#    Epoch 030/100 | Train: 3.1031 | Val: 3.1037 | LR: 8.94e-04 | Time: 39.7s
#       EarlyStopping counter: 2/10
#    Epoch 031/100 | Train: 3.1030 | Val: 3.1037 | LR: 8.83e-04 | Time: 41.3s
#       EarlyStopping counter: 3/10
#    Epoch 032/100 | Train: 3.1029 | Val: 3.1039 | LR: 8.72e-04 | Time: 38.4s
#       EarlyStopping counter: 4/10
#    Epoch 033/100 | Train: 3.1028 | Val: 3.1038 | LR: 8.60e-04 | Time: 37.8s
#       EarlyStopping counter: 5/10
#    Epoch 034/100 | Train: 3.1027 | Val: 3.1037 | LR: 8.47e-04 | Time: 37.6s
#       EarlyStopping counter: 6/10
#    Epoch 035/100 | Train: 3.1026 | Val: 3.1040 | LR: 8.35e-04 | Time: 41.9s
#       EarlyStopping counter: 7/10
#    Epoch 036/100 | Train: 3.1026 | Val: 3.1036 | LR: 8.22e-04 | Time: 39.5s
#       ✓ Val loss improved (3.1037 → 3.1036). Saving...
#    Epoch 037/100 | Train: 3.1025 | Val: 3.1036 | LR: 8.08e-04 | Time: 39.3s
#       EarlyStopping counter: 1/10
#    Epoch 038/100 | Train: 3.1024 | Val: 3.1038 | LR: 7.94e-04 | Time: 39.6s
#       EarlyStopping counter: 2/10
#    Epoch 039/100 | Train: 3.1024 | Val: 3.1037 | LR: 7.80e-04 | Time: 39.6s
#       EarlyStopping counter: 3/10
#    Epoch 040/100 | Train: 3.1023 | Val: 3.1036 | LR: 7.65e-04 | Time: 45.4s
#       EarlyStopping counter: 4/10
#    Epoch 041/100 | Train: 3.1022 | Val: 3.1035 | LR: 7.50e-04 | Time: 39.7s
#       ✓ Val loss improved (3.1036 → 3.1035). Saving...
#    Epoch 042/100 | Train: 3.1021 | Val: 3.1035 | LR: 7.35e-04 | Time: 38.6s
#       ✓ Val loss improved (3.1035 → 3.1035). Saving...
#    Epoch 043/100 | Train: 3.1021 | Val: 3.1034 | LR: 7.19e-04 | Time: 39.7s
#       ✓ Val loss improved (3.1035 → 3.1034). Saving...
#    Epoch 044/100 | Train: 3.1020 | Val: 3.1035 | LR: 7.04e-04 | Time: 40.8s
#       EarlyStopping counter: 1/10
#    Epoch 045/100 | Train: 3.1020 | Val: 3.1035 | LR: 6.88e-04 | Time: 38.4s
#       EarlyStopping counter: 2/10
#    Epoch 046/100 | Train: 3.1019 | Val: 3.1036 | LR: 6.71e-04 | Time: 38.8s
#       EarlyStopping counter: 3/10
#    Epoch 047/100 | Train: 3.1018 | Val: 3.1035 | LR: 6.55e-04 | Time: 41.0s
#       EarlyStopping counter: 4/10
#    Epoch 048/100 | Train: 3.1017 | Val: 3.1036 | LR: 6.38e-04 | Time: 45.2s
#       EarlyStopping counter: 5/10
#    Epoch 049/100 | Train: 3.1017 | Val: 3.1036 | LR: 6.21e-04 | Time: 43.1s
#       EarlyStopping counter: 6/10
#    Epoch 050/100 | Train: 3.1023 | Val: 3.1038 | LR: 6.04e-04 | Time: 37.9s
#       EarlyStopping counter: 7/10
#    Epoch 051/100 | Train: 3.1017 | Val: 3.1036 | LR: 5.87e-04 | Time: 38.2s
#       EarlyStopping counter: 8/10
#    Epoch 052/100 | Train: 3.1015 | Val: 3.1035 | LR: 5.70e-04 | Time: 38.6s
#       EarlyStopping counter: 9/10
#    Epoch 053/100 | Train: 3.1014 | Val: 3.1036 | LR: 5.53e-04 | Time: 42.6s
#       EarlyStopping counter: 10/10
#
#    🛑 Early stopping triggered at epoch 53
#    💾 Final model saved: ./results_crossplatform_B22_eta0.2/final_model_B22_eta0.2_M1.pth
#
#    📈 Evaluating all decoders...
#
#    ✅ RESULTS M=1 (B22, η=0.2):
#       Bi-LSTM:         8.33%
#       Min. Distance:   8.41%
#       KL Divergence:   8.41%
#       Max. Likelihood: 8.41%
#    📈 Training plot saved: ./results_crossplatform_B22_eta0.2/training_plot_B22_eta0.2_M1.png
#
# ======================================================================
# 🔬 EXPERIMENT FOR COVERAGE M = 2
#    Error Model: B22 (Nanopore MinION Short)
#    Eta: 0.2, Vocab Size: 34
#    Seq Length: 136
# ======================================================================
#    📊 Data: 80,000 train | 20,000 validation
#    🧠 Model: 34 classes, 541,218 parameters
#
#    🏋️ Training Configuration:
#       Epochs: 100, Patience: 10
#       Warmup: 10 epochs
#       LR: 0.001 → 1e-06
#    Epoch 001/100 | Train: 3.4779 | Val: 3.3328 | LR: 1.00e-04 | Time: 67.2s
#       ✓ Val loss improved (inf → 3.3328). Saving...
#    Epoch 002/100 | Train: 3.0963 | Val: 2.9701 | LR: 1.90e-04 | Time: 66.9s
#       ✓ Val loss improved (3.3328 → 2.9701). Saving...
#    Epoch 003/100 | Train: 2.9609 | Val: 2.9288 | LR: 2.80e-04 | Time: 66.5s
#       ✓ Val loss improved (2.9701 → 2.9288). Saving...
#    Epoch 004/100 | Train: 2.9207 | Val: 2.8970 | LR: 3.70e-04 | Time: 64.2s
#       ✓ Val loss improved (2.9288 → 2.8970). Saving...
#    Epoch 005/100 | Train: 2.8951 | Val: 2.8867 | LR: 4.60e-04 | Time: 64.2s
#       ✓ Val loss improved (2.8970 → 2.8867). Saving...
#    Epoch 006/100 | Train: 2.8790 | Val: 2.8626 | LR: 5.50e-04 | Time: 64.4s
#       ✓ Val loss improved (2.8867 → 2.8626). Saving...
#    Epoch 007/100 | Train: 2.8638 | Val: 2.8495 | LR: 6.40e-04 | Time: 64.5s
#       ✓ Val loss improved (2.8626 → 2.8495). Saving...
#    Epoch 008/100 | Train: 2.8577 | Val: 2.8437 | LR: 7.30e-04 | Time: 64.9s
#       ✓ Val loss improved (2.8495 → 2.8437). Saving...
#    Epoch 009/100 | Train: 2.8430 | Val: 2.8374 | LR: 8.20e-04 | Time: 67.4s
#       ✓ Val loss improved (2.8437 → 2.8374). Saving...
#    Epoch 010/100 | Train: 2.8363 | Val: 2.8279 | LR: 9.10e-04 | Time: 78.9s
#       ✓ Val loss improved (2.8374 → 2.8279). Saving...
#    Epoch 011/100 | Train: 2.8289 | Val: 2.8212 | LR: 1.00e-03 | Time: 65.1s
#       ✓ Val loss improved (2.8279 → 2.8212). Saving...
#    Epoch 012/100 | Train: 2.8226 | Val: 2.8182 | LR: 1.00e-03 | Time: 65.0s
#       ✓ Val loss improved (2.8212 → 2.8182). Saving...
#    Epoch 013/100 | Train: 2.8156 | Val: 2.8107 | LR: 9.99e-04 | Time: 65.0s
#       ✓ Val loss improved (2.8182 → 2.8107). Saving...
#    Epoch 014/100 | Train: 2.8087 | Val: 2.8033 | LR: 9.97e-04 | Time: 65.5s
#       ✓ Val loss improved (2.8107 → 2.8033). Saving...
#    Epoch 015/100 | Train: 2.8020 | Val: 2.7983 | LR: 9.95e-04 | Time: 75.7s
#       ✓ Val loss improved (2.8033 → 2.7983). Saving...
#    Epoch 016/100 | Train: 2.7974 | Val: 2.7947 | LR: 9.92e-04 | Time: 69.4s
#       ✓ Val loss improved (2.7983 → 2.7947). Saving...
#    Epoch 017/100 | Train: 2.7933 | Val: 2.7902 | LR: 9.89e-04 | Time: 65.7s
#       ✓ Val loss improved (2.7947 → 2.7902). Saving...
#    Epoch 018/100 | Train: 2.7897 | Val: 2.7879 | LR: 9.85e-04 | Time: 64.5s
#       ✓ Val loss improved (2.7902 → 2.7879). Saving...
#    Epoch 019/100 | Train: 2.7871 | Val: 2.7870 | LR: 9.81e-04 | Time: 65.9s
#       ✓ Val loss improved (2.7879 → 2.7870). Saving...
#    Epoch 020/100 | Train: 2.7851 | Val: 2.7846 | LR: 9.76e-04 | Time: 66.0s
#       ✓ Val loss improved (2.7870 → 2.7846). Saving...
#    Epoch 021/100 | Train: 2.7834 | Val: 2.7838 | LR: 9.70e-04 | Time: 65.0s
#       ✓ Val loss improved (2.7846 → 2.7838). Saving...
#    Epoch 022/100 | Train: 2.7812 | Val: 2.7823 | LR: 9.64e-04 | Time: 65.1s
#       ✓ Val loss improved (2.7838 → 2.7823). Saving...
#    Epoch 023/100 | Train: 2.7799 | Val: 2.7808 | LR: 9.57e-04 | Time: 65.4s
#       ✓ Val loss improved (2.7823 → 2.7808). Saving...
#    Epoch 024/100 | Train: 2.7786 | Val: 2.7817 | LR: 9.49e-04 | Time: 64.8s
#       EarlyStopping counter: 1/10
#    Epoch 025/100 | Train: 2.7777 | Val: 2.7783 | LR: 9.42e-04 | Time: 64.2s
#       ✓ Val loss improved (2.7808 → 2.7783). Saving...
#    Epoch 026/100 | Train: 2.7763 | Val: 2.7785 | LR: 9.33e-04 | Time: 64.2s
#       EarlyStopping counter: 1/10
#    Epoch 027/100 | Train: 2.7756 | Val: 2.7785 | LR: 9.24e-04 | Time: 66.0s
#       EarlyStopping counter: 2/10
#    Epoch 028/100 | Train: 2.7746 | Val: 2.7763 | LR: 9.15e-04 | Time: 77.9s
#       ✓ Val loss improved (2.7783 → 2.7763). Saving...
#    Epoch 029/100 | Train: 2.7740 | Val: 2.7759 | LR: 9.05e-04 | Time: 72.7s
#       ✓ Val loss improved (2.7763 → 2.7759). Saving...
#    Epoch 030/100 | Train: 2.7733 | Val: 2.7758 | LR: 8.94e-04 | Time: 68.9s
#       ✓ Val loss improved (2.7759 → 2.7758). Saving...
#    Epoch 031/100 | Train: 2.7727 | Val: 2.7763 | LR: 8.83e-04 | Time: 69.4s
#       EarlyStopping counter: 1/10
#    Epoch 032/100 | Train: 2.7721 | Val: 2.7748 | LR: 8.72e-04 | Time: 69.9s
#       ✓ Val loss improved (2.7758 → 2.7748). Saving...
#    Epoch 033/100 | Train: 2.7711 | Val: 2.7749 | LR: 8.60e-04 | Time: 65.7s
#       EarlyStopping counter: 1/10
#    Epoch 034/100 | Train: 2.7707 | Val: 2.7738 | LR: 8.47e-04 | Time: 72.0s
#       ✓ Val loss improved (2.7748 → 2.7738). Saving...
#    Epoch 035/100 | Train: 2.7701 | Val: 2.7734 | LR: 8.35e-04 | Time: 72.1s
#       ✓ Val loss improved (2.7738 → 2.7734). Saving...
#    Epoch 036/100 | Train: 2.7698 | Val: 2.7732 | LR: 8.22e-04 | Time: 65.2s
#       ✓ Val loss improved (2.7734 → 2.7732). Saving...
#    Epoch 037/100 | Train: 2.7693 | Val: 2.7733 | LR: 8.08e-04 | Time: 69.1s
#       EarlyStopping counter: 1/10
#    Epoch 038/100 | Train: 2.7686 | Val: 2.7733 | LR: 7.94e-04 | Time: 66.2s
#       EarlyStopping counter: 2/10
#    Epoch 039/100 | Train: 2.7683 | Val: 2.7728 | LR: 7.80e-04 | Time: 70.2s
#       ✓ Val loss improved (2.7732 → 2.7728). Saving...
#    Epoch 040/100 | Train: 2.7681 | Val: 2.7719 | LR: 7.65e-04 | Time: 68.1s
#       ✓ Val loss improved (2.7728 → 2.7719). Saving...
#    Epoch 041/100 | Train: 2.7674 | Val: 2.7726 | LR: 7.50e-04 | Time: 66.7s
#       EarlyStopping counter: 1/10
#    Epoch 042/100 | Train: 2.7670 | Val: 2.7719 | LR: 7.35e-04 | Time: 64.6s
#       EarlyStopping counter: 2/10
#    Epoch 043/100 | Train: 2.7665 | Val: 2.7718 | LR: 7.19e-04 | Time: 65.8s
#       ✓ Val loss improved (2.7719 → 2.7718). Saving...
#    Epoch 044/100 | Train: 2.7662 | Val: 2.7716 | LR: 7.04e-04 | Time: 64.8s
#       ✓ Val loss improved (2.7718 → 2.7716). Saving...
#    Epoch 045/100 | Train: 2.7659 | Val: 2.7714 | LR: 6.88e-04 | Time: 65.1s
#       ✓ Val loss improved (2.7716 → 2.7714). Saving...
#    Epoch 046/100 | Train: 2.7654 | Val: 2.7716 | LR: 6.71e-04 | Time: 65.5s
#       EarlyStopping counter: 1/10
#    Epoch 047/100 | Train: 2.7651 | Val: 2.7712 | LR: 6.55e-04 | Time: 64.8s
#       ✓ Val loss improved (2.7714 → 2.7712). Saving...
#    Epoch 048/100 | Train: 2.7646 | Val: 2.7715 | LR: 6.38e-04 | Time: 65.1s
#       EarlyStopping counter: 1/10
#    Epoch 049/100 | Train: 2.7645 | Val: 2.7708 | LR: 6.21e-04 | Time: 65.3s
#       ✓ Val loss improved (2.7712 → 2.7708). Saving...
#    Epoch 050/100 | Train: 2.7641 | Val: 2.7707 | LR: 6.04e-04 | Time: 64.4s
#       ✓ Val loss improved (2.7708 → 2.7707). Saving...
#    Epoch 051/100 | Train: 2.7639 | Val: 2.7708 | LR: 5.87e-04 | Time: 65.2s
#       EarlyStopping counter: 1/10
#    Epoch 052/100 | Train: 2.7636 | Val: 2.7706 | LR: 5.70e-04 | Time: 64.8s
#       ✓ Val loss improved (2.7707 → 2.7706). Saving...
#    Epoch 053/100 | Train: 2.7632 | Val: 2.7705 | LR: 5.53e-04 | Time: 65.4s
#       ✓ Val loss improved (2.7706 → 2.7705). Saving...
#    Epoch 054/100 | Train: 2.7628 | Val: 2.7699 | LR: 5.35e-04 | Time: 66.7s
#       ✓ Val loss improved (2.7705 → 2.7699). Saving...
#    Epoch 055/100 | Train: 2.7626 | Val: 2.7701 | LR: 5.18e-04 | Time: 64.3s
#       EarlyStopping counter: 1/10
#    Epoch 056/100 | Train: 2.7623 | Val: 2.7697 | LR: 5.00e-04 | Time: 64.4s
#       ✓ Val loss improved (2.7699 → 2.7697). Saving...
#    Epoch 057/100 | Train: 2.7621 | Val: 2.7698 | LR: 4.83e-04 | Time: 67.1s
#       EarlyStopping counter: 1/10
#    Epoch 058/100 | Train: 2.7624 | Val: 2.7703 | LR: 4.66e-04 | Time: 65.1s
#       EarlyStopping counter: 2/10
#    Epoch 059/100 | Train: 2.7619 | Val: 2.7701 | LR: 4.48e-04 | Time: 65.7s
#       EarlyStopping counter: 3/10
#    Epoch 060/100 | Train: 2.7616 | Val: 2.7698 | LR: 4.31e-04 | Time: 65.9s
#       EarlyStopping counter: 4/10
#    Epoch 061/100 | Train: 2.7611 | Val: 2.7700 | LR: 4.14e-04 | Time: 65.4s
#       EarlyStopping counter: 5/10
#    Epoch 062/100 | Train: 2.7609 | Val: 2.7700 | LR: 3.97e-04 | Time: 72.3s
#       EarlyStopping counter: 6/10
#    Epoch 063/100 | Train: 2.7605 | Val: 2.7696 | LR: 3.80e-04 | Time: 73.4s
#       ✓ Val loss improved (2.7697 → 2.7696). Saving...
#    Epoch 064/100 | Train: 2.7602 | Val: 2.7698 | LR: 3.63e-04 | Time: 65.0s
#       EarlyStopping counter: 1/10
#    Epoch 065/100 | Train: 2.7600 | Val: 2.7696 | LR: 3.46e-04 | Time: 64.9s
#       EarlyStopping counter: 2/10
#    Epoch 066/100 | Train: 2.7596 | Val: 2.7696 | LR: 3.30e-04 | Time: 65.9s
#       EarlyStopping counter: 3/10
#    Epoch 067/100 | Train: 2.7595 | Val: 2.7705 | LR: 3.13e-04 | Time: 65.2s
#       EarlyStopping counter: 4/10
#    Epoch 068/100 | Train: 2.7593 | Val: 2.7700 | LR: 2.97e-04 | Time: 65.9s
#       EarlyStopping counter: 5/10
#    Epoch 069/100 | Train: 2.7590 | Val: 2.7696 | LR: 2.82e-04 | Time: 66.5s
#       EarlyStopping counter: 6/10
#    Epoch 070/100 | Train: 2.7591 | Val: 2.7695 | LR: 2.66e-04 | Time: 64.6s
#       ✓ Val loss improved (2.7696 → 2.7695). Saving...
#    Epoch 071/100 | Train: 2.7588 | Val: 2.7700 | LR: 2.51e-04 | Time: 65.6s
#       EarlyStopping counter: 1/10
#    Epoch 072/100 | Train: 2.7585 | Val: 2.7698 | LR: 2.36e-04 | Time: 66.2s
#       EarlyStopping counter: 2/10
#    Epoch 073/100 | Train: 2.7583 | Val: 2.7697 | LR: 2.21e-04 | Time: 66.0s
#       EarlyStopping counter: 3/10
#    Epoch 074/100 | Train: 2.7581 | Val: 2.7697 | LR: 2.07e-04 | Time: 65.4s
#       EarlyStopping counter: 4/10
#    Epoch 075/100 | Train: 2.7580 | Val: 2.7694 | LR: 1.93e-04 | Time: 68.9s
#       ✓ Val loss improved (2.7695 → 2.7694). Saving...
#    Epoch 076/100 | Train: 2.7577 | Val: 2.7696 | LR: 1.79e-04 | Time: 64.2s
#       EarlyStopping counter: 1/10
#    Epoch 077/100 | Train: 2.7575 | Val: 2.7694 | LR: 1.66e-04 | Time: 66.3s
#       EarlyStopping counter: 2/10
#    Epoch 078/100 | Train: 2.7574 | Val: 2.7698 | LR: 1.54e-04 | Time: 64.9s
#       EarlyStopping counter: 3/10
#    Epoch 079/100 | Train: 2.7573 | Val: 2.7697 | LR: 1.41e-04 | Time: 65.4s
#       EarlyStopping counter: 4/10
#    Epoch 080/100 | Train: 2.7573 | Val: 2.7701 | LR: 1.29e-04 | Time: 64.4s
#       EarlyStopping counter: 5/10
#    Epoch 081/100 | Train: 2.7570 | Val: 2.7697 | LR: 1.18e-04 | Time: 64.6s
#       EarlyStopping counter: 6/10
#    Epoch 082/100 | Train: 2.7568 | Val: 2.7697 | LR: 1.07e-04 | Time: 71.9s
#       EarlyStopping counter: 7/10
#    Epoch 083/100 | Train: 2.7567 | Val: 2.7698 | LR: 9.64e-05 | Time: 65.4s
#       EarlyStopping counter: 8/10
#    Epoch 084/100 | Train: 2.7566 | Val: 2.7698 | LR: 8.64e-05 | Time: 64.6s
#       EarlyStopping counter: 9/10
#    Epoch 085/100 | Train: 2.7564 | Val: 2.7697 | LR: 7.69e-05 | Time: 64.7s
#       EarlyStopping counter: 10/10
#
#    🛑 Early stopping triggered at epoch 85
#    💾 Final model saved: ./results_crossplatform_B22_eta0.2/final_model_B22_eta0.2_M2.pth
#
#    📈 Evaluating all decoders...
#
#    ✅ RESULTS M=2 (B22, η=0.2):
#       Bi-LSTM:         13.09%
#       Min. Distance:   12.00%
#       KL Divergence:   12.00%
#       Max. Likelihood: 12.00%
#    📈 Training plot saved: ./results_crossplatform_B22_eta0.2/training_plot_B22_eta0.2_M2.png
#
# ======================================================================
# 🔬 EXPERIMENT FOR COVERAGE M = 3
#    Error Model: B22 (Nanopore MinION Short)
#    Eta: 0.2, Vocab Size: 34
#    Seq Length: 136
# ======================================================================
#    📊 Data: 80,000 train | 20,000 validation
#    🧠 Model: 34 classes, 541,218 parameters
#
#    🏋️ Training Configuration:
#       Epochs: 100, Patience: 10
#       Warmup: 10 epochs
#       LR: 0.001 → 1e-06
#    Epoch 001/100 | Train: 3.4752 | Val: 3.3180 | LR: 1.00e-04 | Time: 90.8s
#       ✓ Val loss improved (inf → 3.3180). Saving...
#    Epoch 002/100 | Train: 3.0289 | Val: 2.8401 | LR: 1.90e-04 | Time: 92.0s
#       ✓ Val loss improved (3.3180 → 2.8401). Saving...
#    Epoch 003/100 | Train: 2.8202 | Val: 2.7737 | LR: 2.80e-04 | Time: 92.1s
#       ✓ Val loss improved (2.8401 → 2.7737). Saving...
#    Epoch 004/100 | Train: 2.7630 | Val: 2.7315 | LR: 3.70e-04 | Time: 92.5s
#       ✓ Val loss improved (2.7737 → 2.7315). Saving...
#    Epoch 005/100 | Train: 2.7289 | Val: 2.7106 | LR: 4.60e-04 | Time: 97.6s
#       ✓ Val loss improved (2.7315 → 2.7106). Saving...
#    Epoch 006/100 | Train: 2.7086 | Val: 2.6940 | LR: 5.50e-04 | Time: 98.3s
#       ✓ Val loss improved (2.7106 → 2.6940). Saving...
#    Epoch 007/100 | Train: 2.6932 | Val: 2.6815 | LR: 6.40e-04 | Time: 93.8s
#       ✓ Val loss improved (2.6940 → 2.6815). Saving...
#    Epoch 008/100 | Train: 2.6806 | Val: 2.6728 | LR: 7.30e-04 | Time: 94.6s
#       ✓ Val loss improved (2.6815 → 2.6728). Saving...
#    Epoch 009/100 | Train: 2.6717 | Val: 2.6619 | LR: 8.20e-04 | Time: 95.2s
#       ✓ Val loss improved (2.6728 → 2.6619). Saving...
#    Epoch 010/100 | Train: 2.6608 | Val: 2.6517 | LR: 9.10e-04 | Time: 95.4s
#       ✓ Val loss improved (2.6619 → 2.6517). Saving...
#    Epoch 011/100 | Train: 2.6540 | Val: 2.6471 | LR: 1.00e-03 | Time: 93.5s
#       ✓ Val loss improved (2.6517 → 2.6471). Saving...
#    Epoch 012/100 | Train: 2.6482 | Val: 2.6424 | LR: 1.00e-03 | Time: 94.3s
#       ✓ Val loss improved (2.6471 → 2.6424). Saving...
#    Epoch 013/100 | Train: 2.6428 | Val: 2.6370 | LR: 9.99e-04 | Time: 94.9s
#       ✓ Val loss improved (2.6424 → 2.6370). Saving...
#    Epoch 014/100 | Train: 2.6369 | Val: 2.6321 | LR: 9.97e-04 | Time: 99.9s
#       ✓ Val loss improved (2.6370 → 2.6321). Saving...
#    Epoch 015/100 | Train: 2.6325 | Val: 2.6317 | LR: 9.95e-04 | Time: 93.9s
#       ✓ Val loss improved (2.6321 → 2.6317). Saving...
#    Epoch 016/100 | Train: 2.6287 | Val: 2.6246 | LR: 9.92e-04 | Time: 95.1s
#       ✓ Val loss improved (2.6317 → 2.6246). Saving...
#    Epoch 017/100 | Train: 2.6247 | Val: 2.6211 | LR: 9.89e-04 | Time: 146.9s
#       ✓ Val loss improved (2.6246 → 2.6211). Saving...
#    Epoch 018/100 | Train: 2.6215 | Val: 2.6191 | LR: 9.85e-04 | Time: 149.9s
#       ✓ Val loss improved (2.6211 → 2.6191). Saving...
#    Epoch 019/100 | Train: 2.6185 | Val: 2.6159 | LR: 9.81e-04 | Time: 143.9s
#       ✓ Val loss improved (2.6191 → 2.6159). Saving...
#    Epoch 020/100 | Train: 2.6156 | Val: 2.6125 | LR: 9.76e-04 | Time: 148.5s
#       ✓ Val loss improved (2.6159 → 2.6125). Saving...
#    Epoch 021/100 | Train: 2.6123 | Val: 2.6101 | LR: 9.70e-04 | Time: 153.4s
#       ✓ Val loss improved (2.6125 → 2.6101). Saving...
#    Epoch 022/100 | Train: 2.6083 | Val: 2.6059 | LR: 9.64e-04 | Time: 145.7s
#       ✓ Val loss improved (2.6101 → 2.6059). Saving...
#    Epoch 023/100 | Train: 2.6043 | Val: 2.6015 | LR: 9.57e-04 | Time: 146.1s
#       ✓ Val loss improved (2.6059 → 2.6015). Saving...
#    Epoch 024/100 | Train: 2.5999 | Val: 2.5978 | LR: 9.49e-04 | Time: 143.2s
#       ✓ Val loss improved (2.6015 → 2.5978). Saving...
#    Epoch 025/100 | Train: 2.5960 | Val: 2.5963 | LR: 9.42e-04 | Time: 142.6s
#       ✓ Val loss improved (2.5978 → 2.5963). Saving...
#    Epoch 026/100 | Train: 2.5924 | Val: 2.5920 | LR: 9.33e-04 | Time: 137.9s
#       ✓ Val loss improved (2.5963 → 2.5920). Saving...
#    Epoch 027/100 | Train: 2.5892 | Val: 2.5874 | LR: 9.24e-04 | Time: 151.0s
#       ✓ Val loss improved (2.5920 → 2.5874). Saving...
#    Epoch 028/100 | Train: 2.5859 | Val: 2.5863 | LR: 9.15e-04 | Time: 142.3s
#       ✓ Val loss improved (2.5874 → 2.5863). Saving...
#    Epoch 029/100 | Train: 2.5829 | Val: 2.5830 | LR: 9.05e-04 | Time: 148.8s
#       ✓ Val loss improved (2.5863 → 2.5830). Saving...
#    Epoch 030/100 | Train: 2.5793 | Val: 2.5792 | LR: 8.94e-04 | Time: 131.5s
#       ✓ Val loss improved (2.5830 → 2.5792). Saving...
#    Epoch 031/100 | Train: 2.5769 | Val: 2.5782 | LR: 8.83e-04 | Time: 95.0s
#       ✓ Val loss improved (2.5792 → 2.5782). Saving...
#    Epoch 032/100 | Train: 2.5744 | Val: 2.5760 | LR: 8.72e-04 | Time: 105.2s
#       ✓ Val loss improved (2.5782 → 2.5760). Saving...
#    Epoch 033/100 | Train: 2.5720 | Val: 2.5728 | LR: 8.60e-04 | Time: 104.5s
#       ✓ Val loss improved (2.5760 → 2.5728). Saving...
#    Epoch 034/100 | Train: 2.5702 | Val: 2.5716 | LR: 8.47e-04 | Time: 94.7s
#       ✓ Val loss improved (2.5728 → 2.5716). Saving...
#    Epoch 035/100 | Train: 2.5679 | Val: 2.5702 | LR: 8.35e-04 | Time: 95.4s
#       ✓ Val loss improved (2.5716 → 2.5702). Saving...
#    Epoch 036/100 | Train: 2.5666 | Val: 2.5692 | LR: 8.22e-04 | Time: 95.2s
#       ✓ Val loss improved (2.5702 → 2.5692). Saving...
#    Epoch 037/100 | Train: 2.5650 | Val: 2.5693 | LR: 8.08e-04 | Time: 95.1s
#       EarlyStopping counter: 1/10
#    Epoch 038/100 | Train: 2.5631 | Val: 2.5689 | LR: 7.94e-04 | Time: 104.9s
#       ✓ Val loss improved (2.5692 → 2.5689). Saving...
#    Epoch 039/100 | Train: 2.5618 | Val: 2.5653 | LR: 7.80e-04 | Time: 95.0s
#       ✓ Val loss improved (2.5689 → 2.5653). Saving...
#    Epoch 040/100 | Train: 2.5602 | Val: 2.5640 | LR: 7.65e-04 | Time: 97.4s
#       ✓ Val loss improved (2.5653 → 2.5640). Saving...
#    Epoch 041/100 | Train: 2.5591 | Val: 2.5641 | LR: 7.50e-04 | Time: 105.3s
#       EarlyStopping counter: 1/10
#    Epoch 042/100 | Train: 2.5579 | Val: 2.5630 | LR: 7.35e-04 | Time: 102.5s
#       ✓ Val loss improved (2.5640 → 2.5630). Saving...
#    Epoch 043/100 | Train: 2.5562 | Val: 2.5622 | LR: 7.19e-04 | Time: 94.3s
#       ✓ Val loss improved (2.5630 → 2.5622). Saving...
#    Epoch 044/100 | Train: 2.5553 | Val: 2.5621 | LR: 7.04e-04 | Time: 101.2s
#       ✓ Val loss improved (2.5622 → 2.5621). Saving...
#    Epoch 045/100 | Train: 2.5543 | Val: 2.5618 | LR: 6.88e-04 | Time: 94.2s
#       ✓ Val loss improved (2.5621 → 2.5618). Saving...
#    Epoch 046/100 | Train: 2.5529 | Val: 2.5603 | LR: 6.71e-04 | Time: 94.4s
#       ✓ Val loss improved (2.5618 → 2.5603). Saving...
#    Epoch 047/100 | Train: 2.5523 | Val: 2.5597 | LR: 6.55e-04 | Time: 94.6s
#       ✓ Val loss improved (2.5603 → 2.5597). Saving...
#    Epoch 048/100 | Train: 2.5509 | Val: 2.5591 | LR: 6.38e-04 | Time: 95.3s
#       ✓ Val loss improved (2.5597 → 2.5591). Saving...
#    Epoch 049/100 | Train: 2.5501 | Val: 2.5586 | LR: 6.21e-04 | Time: 95.4s
#       ✓ Val loss improved (2.5591 → 2.5586). Saving...
#    Epoch 050/100 | Train: 2.5492 | Val: 2.5591 | LR: 6.04e-04 | Time: 93.3s
#       EarlyStopping counter: 1/10
#    Epoch 051/100 | Train: 2.5483 | Val: 2.5574 | LR: 5.87e-04 | Time: 98.0s
#       ✓ Val loss improved (2.5586 → 2.5574). Saving...
#    Epoch 052/100 | Train: 2.5474 | Val: 2.5575 | LR: 5.70e-04 | Time: 94.5s
#       EarlyStopping counter: 1/10
#    Epoch 053/100 | Train: 2.5468 | Val: 2.5594 | LR: 5.53e-04 | Time: 93.2s
#       EarlyStopping counter: 2/10
#    Epoch 054/100 | Train: 2.5461 | Val: 2.5577 | LR: 5.35e-04 | Time: 93.5s
#       EarlyStopping counter: 3/10
#    Epoch 055/100 | Train: 2.5450 | Val: 2.5569 | LR: 5.18e-04 | Time: 93.2s
#       ✓ Val loss improved (2.5574 → 2.5569). Saving...
#    Epoch 056/100 | Train: 2.5442 | Val: 2.5580 | LR: 5.00e-04 | Time: 100.4s
#       EarlyStopping counter: 1/10
#    Epoch 057/100 | Train: 2.5441 | Val: 2.5567 | LR: 4.83e-04 | Time: 95.9s
#       ✓ Val loss improved (2.5569 → 2.5567). Saving...
#    Epoch 058/100 | Train: 2.5429 | Val: 2.5580 | LR: 4.66e-04 | Time: 102.4s
#       EarlyStopping counter: 1/10
#    Epoch 059/100 | Train: 2.5420 | Val: 2.5558 | LR: 4.48e-04 | Time: 111.5s
#       ✓ Val loss improved (2.5567 → 2.5558). Saving...
#    Epoch 060/100 | Train: 2.5418 | Val: 2.5570 | LR: 4.31e-04 | Time: 97.9s
#       EarlyStopping counter: 1/10
#    Epoch 061/100 | Train: 2.5409 | Val: 2.5554 | LR: 4.14e-04 | Time: 97.9s
#       ✓ Val loss improved (2.5558 → 2.5554). Saving...
#    Epoch 062/100 | Train: 2.5399 | Val: 2.5563 | LR: 3.97e-04 | Time: 94.5s
#       EarlyStopping counter: 1/10
#    Epoch 063/100 | Train: 2.5393 | Val: 2.5567 | LR: 3.80e-04 | Time: 93.2s
#       EarlyStopping counter: 2/10
#    Epoch 064/100 | Train: 2.5387 | Val: 2.5576 | LR: 3.63e-04 | Time: 94.0s
#       EarlyStopping counter: 3/10
#    Epoch 065/100 | Train: 2.5380 | Val: 2.5553 | LR: 3.46e-04 | Time: 93.4s
#       ✓ Val loss improved (2.5554 → 2.5553). Saving...
#    Epoch 066/100 | Train: 2.5376 | Val: 2.5555 | LR: 3.30e-04 | Time: 94.0s
#       EarlyStopping counter: 1/10
#    Epoch 067/100 | Train: 2.5372 | Val: 2.5562 | LR: 3.13e-04 | Time: 94.2s
#       EarlyStopping counter: 2/10
#    Epoch 068/100 | Train: 2.5365 | Val: 2.5554 | LR: 2.97e-04 | Time: 92.5s
#       EarlyStopping counter: 3/10
#    Epoch 069/100 | Train: 2.5358 | Val: 2.5568 | LR: 2.82e-04 | Time: 92.6s
#       EarlyStopping counter: 4/10
#    Epoch 070/100 | Train: 2.5354 | Val: 2.5558 | LR: 2.66e-04 | Time: 94.3s
#       EarlyStopping counter: 5/10
#    Epoch 071/100 | Train: 2.5349 | Val: 2.5562 | LR: 2.51e-04 | Time: 94.2s
#       EarlyStopping counter: 6/10
#    Epoch 072/100 | Train: 2.5343 | Val: 2.5563 | LR: 2.36e-04 | Time: 95.1s
#       EarlyStopping counter: 7/10
#    Epoch 073/100 | Train: 2.5339 | Val: 2.5567 | LR: 2.21e-04 | Time: 95.1s
#       EarlyStopping counter: 8/10
#    Epoch 074/100 | Train: 2.5337 | Val: 2.5557 | LR: 2.07e-04 | Time: 106.7s
#       EarlyStopping counter: 9/10
#    Epoch 075/100 | Train: 2.5330 | Val: 2.5561 | LR: 1.93e-04 | Time: 96.8s
#       EarlyStopping counter: 10/10
#
#    🛑 Early stopping triggered at epoch 75
#    💾 Final model saved: ./results_crossplatform_B22_eta0.2/final_model_B22_eta0.2_M3.pth
#
#    📈 Evaluating all decoders...
#
#    ✅ RESULTS M=3 (B22, η=0.2):
#       Bi-LSTM:         16.84%
#       Min. Distance:   14.16%
#       KL Divergence:   14.16%
#       Max. Likelihood: 14.16%
#    📈 Training plot saved: ./results_crossplatform_B22_eta0.2/training_plot_B22_eta0.2_M3.png
#
# ======================================================================
# 🔬 EXPERIMENT FOR COVERAGE M = 5
#    Error Model: B22 (Nanopore MinION Short)
#    Eta: 0.2, Vocab Size: 34
#    Seq Length: 136
# ======================================================================
#    📊 Data: 80,000 train | 20,000 validation
#    🧠 Model: 34 classes, 541,218 parameters
#
#    🏋️ Training Configuration:
#       Epochs: 100, Patience: 10
#       Warmup: 10 epochs
#       LR: 0.001 → 1e-06
#    Epoch 001/100 | Train: 3.4745 | Val: 3.3138 | LR: 1.00e-04 | Time: 227.7s
#       ✓ Val loss improved (inf → 3.3138). Saving...
#    Epoch 002/100 | Train: 2.9567 | Val: 2.6660 | LR: 1.90e-04 | Time: 228.1s
#       ✓ Val loss improved (3.3138 → 2.6660). Saving...
#    Epoch 003/100 | Train: 2.6273 | Val: 2.5594 | LR: 2.80e-04 | Time: 226.4s
#       ✓ Val loss improved (2.6660 → 2.5594). Saving...
#    Epoch 004/100 | Train: 2.5471 | Val: 2.5024 | LR: 3.70e-04 | Time: 234.4s
#       ✓ Val loss improved (2.5594 → 2.5024). Saving...
#    Epoch 005/100 | Train: 2.5037 | Val: 2.4814 | LR: 4.60e-04 | Time: 231.2s
#       ✓ Val loss improved (2.5024 → 2.4814). Saving...
#    Epoch 006/100 | Train: 2.4751 | Val: 2.4478 | LR: 5.50e-04 | Time: 223.3s
#       ✓ Val loss improved (2.4814 → 2.4478). Saving...
#    Epoch 007/100 | Train: 2.4511 | Val: 2.4282 | LR: 6.40e-04 | Time: 222.3s
#       ✓ Val loss improved (2.4478 → 2.4282). Saving...
#    Epoch 008/100 | Train: 2.4368 | Val: 2.4149 | LR: 7.30e-04 | Time: 222.8s
#       ✓ Val loss improved (2.4282 → 2.4149). Saving...
#    Epoch 009/100 | Train: 2.4211 | Val: 2.4095 | LR: 8.20e-04 | Time: 209.5s
#       ✓ Val loss improved (2.4149 → 2.4095). Saving...
#    Epoch 010/100 | Train: 2.4122 | Val: 2.3963 | LR: 9.10e-04 | Time: 147.1s
#       ✓ Val loss improved (2.4095 → 2.3963). Saving...
#    Epoch 011/100 | Train: 2.4033 | Val: 2.3909 | LR: 1.00e-03 | Time: 149.3s
#       ✓ Val loss improved (2.3963 → 2.3909). Saving...
#    Epoch 012/100 | Train: 2.3959 | Val: 2.3835 | LR: 1.00e-03 | Time: 148.0s
#       ✓ Val loss improved (2.3909 → 2.3835). Saving...
#    Epoch 013/100 | Train: 2.3904 | Val: 2.3841 | LR: 9.99e-04 | Time: 158.1s
#       EarlyStopping counter: 1/10
#    Epoch 014/100 | Train: 2.3842 | Val: 2.3736 | LR: 9.97e-04 | Time: 151.0s
#       ✓ Val loss improved (2.3835 → 2.3736). Saving...
#    Epoch 015/100 | Train: 2.3787 | Val: 2.3741 | LR: 9.95e-04 | Time: 150.7s
#       EarlyStopping counter: 1/10
#    Epoch 016/100 | Train: 2.3725 | Val: 2.3604 | LR: 9.92e-04 | Time: 151.2s
#       ✓ Val loss improved (2.3736 → 2.3604). Saving...
#    Epoch 017/100 | Train: 2.3645 | Val: 2.3529 | LR: 9.89e-04 | Time: 148.3s
#       ✓ Val loss improved (2.3604 → 2.3529). Saving...
#    Epoch 018/100 | Train: 2.3571 | Val: 2.3482 | LR: 9.85e-04 | Time: 161.8s
#       ✓ Val loss improved (2.3529 → 2.3482). Saving...
#    Epoch 019/100 | Train: 2.3494 | Val: 2.3392 | LR: 9.81e-04 | Time: 153.2s
#       ✓ Val loss improved (2.3482 → 2.3392). Saving...
#    Epoch 020/100 | Train: 2.3444 | Val: 2.3376 | LR: 9.76e-04 | Time: 149.1s
#       ✓ Val loss improved (2.3392 → 2.3376). Saving...
#    Epoch 021/100 | Train: 2.3404 | Val: 2.3319 | LR: 9.70e-04 | Time: 150.6s
#       ✓ Val loss improved (2.3376 → 2.3319). Saving...
#    Epoch 022/100 | Train: 2.3353 | Val: 2.3280 | LR: 9.64e-04 | Time: 147.8s
#       ✓ Val loss improved (2.3319 → 2.3280). Saving...
#    Epoch 023/100 | Train: 2.3308 | Val: 2.3236 | LR: 9.57e-04 | Time: 149.0s
#       ✓ Val loss improved (2.3280 → 2.3236). Saving...
#    Epoch 024/100 | Train: 2.3272 | Val: 2.3241 | LR: 9.49e-04 | Time: 154.9s
#       EarlyStopping counter: 1/10
#    Epoch 025/100 | Train: 2.3232 | Val: 2.3151 | LR: 9.42e-04 | Time: 148.2s
#       ✓ Val loss improved (2.3236 → 2.3151). Saving...
#    Epoch 026/100 | Train: 2.3201 | Val: 2.3147 | LR: 9.33e-04 | Time: 158.5s
#       ✓ Val loss improved (2.3151 → 2.3147). Saving...
#    Epoch 027/100 | Train: 2.3182 | Val: 2.3116 | LR: 9.24e-04 | Time: 148.4s
#       ✓ Val loss improved (2.3147 → 2.3116). Saving...
#    Epoch 028/100 | Train: 2.3141 | Val: 2.3102 | LR: 9.15e-04 | Time: 161.3s
#       ✓ Val loss improved (2.3116 → 2.3102). Saving...
#    Epoch 029/100 | Train: 2.3122 | Val: 2.3082 | LR: 9.05e-04 | Time: 151.5s
#       ✓ Val loss improved (2.3102 → 2.3082). Saving...
#    Epoch 030/100 | Train: 2.3088 | Val: 2.3093 | LR: 8.94e-04 | Time: 147.4s
#       EarlyStopping counter: 1/10
#    Epoch 031/100 | Train: 2.3073 | Val: 2.3034 | LR: 8.83e-04 | Time: 147.2s
#       ✓ Val loss improved (2.3082 → 2.3034). Saving...
#    Epoch 032/100 | Train: 2.3053 | Val: 2.3027 | LR: 8.72e-04 | Time: 148.7s
#       ✓ Val loss improved (2.3034 → 2.3027). Saving...
#    Epoch 033/100 | Train: 2.3022 | Val: 2.3031 | LR: 8.60e-04 | Time: 148.2s
#       EarlyStopping counter: 1/10
#    Epoch 034/100 | Train: 2.3010 | Val: 2.3012 | LR: 8.47e-04 | Time: 155.5s
#       ✓ Val loss improved (2.3027 → 2.3012). Saving...
#    Epoch 035/100 | Train: 2.2984 | Val: 2.3006 | LR: 8.35e-04 | Time: 179.1s
#       ✓ Val loss improved (2.3012 → 2.3006). Saving...
#    Epoch 036/100 | Train: 2.2968 | Val: 2.2989 | LR: 8.22e-04 | Time: 151.8s
#       ✓ Val loss improved (2.3006 → 2.2989). Saving...
#    Epoch 037/100 | Train: 2.2951 | Val: 2.2953 | LR: 8.08e-04 | Time: 147.4s
#       ✓ Val loss improved (2.2989 → 2.2953). Saving...
#    Epoch 038/100 | Train: 2.2938 | Val: 2.2966 | LR: 7.94e-04 | Time: 148.4s
#       EarlyStopping counter: 1/10
#    Epoch 039/100 | Train: 2.2921 | Val: 2.2958 | LR: 7.80e-04 | Time: 149.0s
#       EarlyStopping counter: 2/10
#    Epoch 040/100 | Train: 2.2906 | Val: 2.2948 | LR: 7.65e-04 | Time: 149.5s
#       ✓ Val loss improved (2.2953 → 2.2948). Saving...
#    Epoch 041/100 | Train: 2.2889 | Val: 2.2957 | LR: 7.50e-04 | Time: 147.6s
#       EarlyStopping counter: 1/10
#    Epoch 042/100 | Train: 2.2876 | Val: 2.2916 | LR: 7.35e-04 | Time: 147.0s
#       ✓ Val loss improved (2.2948 → 2.2916). Saving...
#    Epoch 043/100 | Train: 2.2869 | Val: 2.2903 | LR: 7.19e-04 | Time: 146.0s
#       ✓ Val loss improved (2.2916 → 2.2903). Saving...
#    Epoch 044/100 | Train: 2.2857 | Val: 2.2906 | LR: 7.04e-04 | Time: 147.1s
#       EarlyStopping counter: 1/10
#    Epoch 045/100 | Train: 2.2836 | Val: 2.2917 | LR: 6.88e-04 | Time: 147.7s
#       EarlyStopping counter: 2/10
#    Epoch 046/100 | Train: 2.2829 | Val: 2.2931 | LR: 6.71e-04 | Time: 147.8s
#       EarlyStopping counter: 3/10
#    Epoch 047/100 | Train: 2.2812 | Val: 2.2865 | LR: 6.55e-04 | Time: 149.4s
#       ✓ Val loss improved (2.2903 → 2.2865). Saving...
#    Epoch 048/100 | Train: 2.2799 | Val: 2.2857 | LR: 6.38e-04 | Time: 147.3s
#       ✓ Val loss improved (2.2865 → 2.2857). Saving...
#    Epoch 049/100 | Train: 2.2788 | Val: 2.2875 | LR: 6.21e-04 | Time: 148.2s
#       EarlyStopping counter: 1/10
#    Epoch 050/100 | Train: 2.2784 | Val: 2.2860 | LR: 6.04e-04 | Time: 149.4s
#       EarlyStopping counter: 2/10
#    Epoch 051/100 | Train: 2.2769 | Val: 2.2846 | LR: 5.87e-04 | Time: 147.5s
#       ✓ Val loss improved (2.2857 → 2.2846). Saving...
#    Epoch 052/100 | Train: 2.2760 | Val: 2.2856 | LR: 5.70e-04 | Time: 147.3s
#       EarlyStopping counter: 1/10
#    Epoch 053/100 | Train: 2.2747 | Val: 2.2843 | LR: 5.53e-04 | Time: 148.2s
#       ✓ Val loss improved (2.2846 → 2.2843). Saving...
#    Epoch 054/100 | Train: 2.2738 | Val: 2.2855 | LR: 5.35e-04 | Time: 147.1s
#       EarlyStopping counter: 1/10
#    Epoch 055/100 | Train: 2.2730 | Val: 2.2832 | LR: 5.18e-04 | Time: 146.4s
#       ✓ Val loss improved (2.2843 → 2.2832). Saving...
#    Epoch 056/100 | Train: 2.2718 | Val: 2.2843 | LR: 5.00e-04 | Time: 146.1s
#       EarlyStopping counter: 1/10
#    Epoch 057/100 | Train: 2.2712 | Val: 2.2859 | LR: 4.83e-04 | Time: 152.6s
#       EarlyStopping counter: 2/10
#    Epoch 058/100 | Train: 2.2703 | Val: 2.2820 | LR: 4.66e-04 | Time: 159.1s
#       ✓ Val loss improved (2.2832 → 2.2820). Saving...
#    Epoch 059/100 | Train: 2.2697 | Val: 2.2827 | LR: 4.48e-04 | Time: 158.8s
#       EarlyStopping counter: 1/10
#    Epoch 060/100 | Train: 2.2687 | Val: 2.2880 | LR: 4.31e-04 | Time: 146.4s
#       EarlyStopping counter: 2/10
#    Epoch 061/100 | Train: 2.2678 | Val: 2.2823 | LR: 4.14e-04 | Time: 147.9s
#       EarlyStopping counter: 3/10
#    Epoch 062/100 | Train: 2.2676 | Val: 2.2830 | LR: 3.97e-04 | Time: 147.7s
#       EarlyStopping counter: 4/10
#    Epoch 063/100 | Train: 2.2662 | Val: 2.2811 | LR: 3.80e-04 | Time: 147.3s
#       ✓ Val loss improved (2.2820 → 2.2811). Saving...
#    Epoch 064/100 | Train: 2.2659 | Val: 2.2814 | LR: 3.63e-04 | Time: 147.4s
#       EarlyStopping counter: 1/10
#    Epoch 065/100 | Train: 2.2652 | Val: 2.2809 | LR: 3.46e-04 | Time: 147.4s
#       ✓ Val loss improved (2.2811 → 2.2809). Saving...
#    Epoch 066/100 | Train: 2.2640 | Val: 2.2809 | LR: 3.30e-04 | Time: 149.2s
#       ✓ Val loss improved (2.2809 → 2.2809). Saving...
#    Epoch 067/100 | Train: 2.2637 | Val: 2.2795 | LR: 3.13e-04 | Time: 146.8s
#       ✓ Val loss improved (2.2809 → 2.2795). Saving...
#    Epoch 068/100 | Train: 2.2631 | Val: 2.2809 | LR: 2.97e-04 | Time: 147.3s
#       EarlyStopping counter: 1/10
#    Epoch 069/100 | Train: 2.2627 | Val: 2.2794 | LR: 2.82e-04 | Time: 164.1s
#       ✓ Val loss improved (2.2795 → 2.2794). Saving...
#    Epoch 070/100 | Train: 2.2619 | Val: 2.2801 | LR: 2.66e-04 | Time: 150.5s
#       EarlyStopping counter: 1/10
#    Epoch 071/100 | Train: 2.2607 | Val: 2.2803 | LR: 2.51e-04 | Time: 147.8s
#       EarlyStopping counter: 2/10
#    Epoch 072/100 | Train: 2.2607 | Val: 2.2795 | LR: 2.36e-04 | Time: 148.6s
#       EarlyStopping counter: 3/10
#    Epoch 073/100 | Train: 2.2597 | Val: 2.2792 | LR: 2.21e-04 | Time: 148.9s
#       ✓ Val loss improved (2.2794 → 2.2792). Saving...
#    Epoch 074/100 | Train: 2.2592 | Val: 2.2799 | LR: 2.07e-04 | Time: 162.3s
#       EarlyStopping counter: 1/10
#    Epoch 075/100 | Train: 2.2588 | Val: 2.2790 | LR: 1.93e-04 | Time: 173.3s
#       ✓ Val loss improved (2.2792 → 2.2790). Saving...
#    Epoch 076/100 | Train: 2.2583 | Val: 2.2794 | LR: 1.79e-04 | Time: 150.1s
#       EarlyStopping counter: 1/10
#    Epoch 077/100 | Train: 2.2577 | Val: 2.2792 | LR: 1.66e-04 | Time: 146.3s
#       EarlyStopping counter: 2/10
#    Epoch 078/100 | Train: 2.2573 | Val: 2.2784 | LR: 1.54e-04 | Time: 147.9s
#       ✓ Val loss improved (2.2790 → 2.2784). Saving...
#    Epoch 079/100 | Train: 2.2567 | Val: 2.2801 | LR: 1.41e-04 | Time: 156.4s
#       EarlyStopping counter: 1/10
#    Epoch 080/100 | Train: 2.2567 | Val: 2.2800 | LR: 1.29e-04 | Time: 162.5s
#       EarlyStopping counter: 2/10
#    Epoch 081/100 | Train: 2.2562 | Val: 2.2792 | LR: 1.18e-04 | Time: 162.0s
#       EarlyStopping counter: 3/10
#    Epoch 082/100 | Train: 2.2559 | Val: 2.2797 | LR: 1.07e-04 | Time: 148.0s
#       EarlyStopping counter: 4/10
#    Epoch 083/100 | Train: 2.2556 | Val: 2.2785 | LR: 9.64e-05 | Time: 147.2s
#       EarlyStopping counter: 5/10
#    Epoch 084/100 | Train: 2.2554 | Val: 2.2789 | LR: 8.64e-05 | Time: 147.4s
#       EarlyStopping counter: 6/10
#    Epoch 085/100 | Train: 2.2548 | Val: 2.2782 | LR: 7.69e-05 | Time: 148.6s
#       ✓ Val loss improved (2.2784 → 2.2782). Saving...
#    Epoch 086/100 | Train: 2.2547 | Val: 2.2783 | LR: 6.79e-05 | Time: 147.4s
#       EarlyStopping counter: 1/10
#    Epoch 087/100 | Train: 2.2544 | Val: 2.2782 | LR: 5.95e-05 | Time: 148.9s
#       ✓ Val loss improved (2.2782 → 2.2782). Saving...
#    Epoch 088/100 | Train: 2.2541 | Val: 2.2783 | LR: 5.16e-05 | Time: 146.8s
#       EarlyStopping counter: 1/10
#    Epoch 089/100 | Train: 2.2540 | Val: 2.2782 | LR: 4.42e-05 | Time: 158.8s
#       ✓ Val loss improved (2.2782 → 2.2782). Saving...
#    Epoch 090/100 | Train: 2.2541 | Val: 2.2781 | LR: 3.74e-05 | Time: 152.1s
#       ✓ Val loss improved (2.2782 → 2.2781). Saving...
#    Epoch 091/100 | Train: 2.2536 | Val: 2.2787 | LR: 3.11e-05 | Time: 160.2s
#       EarlyStopping counter: 1/10
#    Epoch 092/100 | Train: 2.2535 | Val: 2.2783 | LR: 2.54e-05 | Time: 147.5s
#       EarlyStopping counter: 2/10
#    Epoch 093/100 | Train: 2.2532 | Val: 2.2785 | LR: 2.03e-05 | Time: 156.0s
#       EarlyStopping counter: 3/10
#    Epoch 094/100 | Train: 2.2532 | Val: 2.2784 | LR: 1.58e-05 | Time: 147.9s
#       EarlyStopping counter: 4/10
#    Epoch 095/100 | Train: 2.2531 | Val: 2.2782 | LR: 1.19e-05 | Time: 146.4s
#       EarlyStopping counter: 5/10
#    Epoch 096/100 | Train: 2.2530 | Val: 2.2783 | LR: 8.59e-06 | Time: 157.7s
#       EarlyStopping counter: 6/10
#    Epoch 097/100 | Train: 2.2529 | Val: 2.2785 | LR: 5.86e-06 | Time: 148.7s
#       EarlyStopping counter: 7/10
#    Epoch 098/100 | Train: 2.2529 | Val: 2.2783 | LR: 3.74e-06 | Time: 147.6s
#       EarlyStopping counter: 8/10
#    Epoch 099/100 | Train: 2.2528 | Val: 2.2784 | LR: 2.22e-06 | Time: 147.7s
#       EarlyStopping counter: 9/10
#    Epoch 100/100 | Train: 2.2528 | Val: 2.2784 | LR: 1.30e-06 | Time: 148.5s
#       EarlyStopping counter: 10/10
#
#    🛑 Early stopping triggered at epoch 100
#    💾 Final model saved: ./results_crossplatform_B22_eta0.2/final_model_B22_eta0.2_M5.pth
#
#    📈 Evaluating all decoders...
#
#    ✅ RESULTS M=5 (B22, η=0.2):
#       Bi-LSTM:         21.61%
#       Min. Distance:   17.29%
#       KL Divergence:   16.50%
#       Max. Likelihood: 16.50%
#    📈 Training plot saved: ./results_crossplatform_B22_eta0.2/training_plot_B22_eta0.2_M5.png
#
# ======================================================================
# 🔬 EXPERIMENT FOR COVERAGE M = 8
#    Error Model: B22 (Nanopore MinION Short)
#    Eta: 0.2, Vocab Size: 34
#    Seq Length: 136
# ======================================================================
#    📊 Data: 80,000 train | 20,000 validation
#    🧠 Model: 34 classes, 541,218 parameters
#
#    🏋️ Training Configuration:
#       Epochs: 100, Patience: 10
#       Warmup: 10 epochs
#       LR: 0.001 → 1e-06
#    Epoch 001/100 | Train: 3.4734 | Val: 3.3062 | LR: 1.00e-04 | Time: 235.8s
#       ✓ Val loss improved (inf → 3.3062). Saving...
#    Epoch 002/100 | Train: 2.9103 | Val: 2.5287 | LR: 1.90e-04 | Time: 256.8s
#       ✓ Val loss improved (3.3062 → 2.5287). Saving...
#    Epoch 003/100 | Train: 2.4454 | Val: 2.3541 | LR: 2.80e-04 | Time: 237.6s
#       ✓ Val loss improved (2.5287 → 2.3541). Saving...
#    Epoch 004/100 | Train: 2.3311 | Val: 2.2803 | LR: 3.70e-04 | Time: 235.7s
#       ✓ Val loss improved (2.3541 → 2.2803). Saving...
#    Epoch 005/100 | Train: 2.2818 | Val: 2.2372 | LR: 4.60e-04 | Time: 230.5s
#       ✓ Val loss improved (2.2803 → 2.2372). Saving...
#    Epoch 006/100 | Train: 2.2430 | Val: 2.2049 | LR: 5.50e-04 | Time: 233.6s
#       ✓ Val loss improved (2.2372 → 2.2049). Saving...
#    Epoch 007/100 | Train: 2.2101 | Val: 2.1782 | LR: 6.40e-04 | Time: 230.9s
#       ✓ Val loss improved (2.2049 → 2.1782). Saving...
#    Epoch 008/100 | Train: 2.1846 | Val: 2.1583 | LR: 7.30e-04 | Time: 237.5s
#       ✓ Val loss improved (2.1782 → 2.1583). Saving...
#    Epoch 009/100 | Train: 2.1670 | Val: 2.1454 | LR: 8.20e-04 | Time: 235.2s
#       ✓ Val loss improved (2.1583 → 2.1454). Saving...
#    Epoch 010/100 | Train: 2.1551 | Val: 2.1359 | LR: 9.10e-04 | Time: 230.8s
#       ✓ Val loss improved (2.1454 → 2.1359). Saving...
#    Epoch 011/100 | Train: 2.1423 | Val: 2.1258 | LR: 1.00e-03 | Time: 228.3s
#       ✓ Val loss improved (2.1359 → 2.1258). Saving...
#    Epoch 012/100 | Train: 2.1327 | Val: 2.1129 | LR: 1.00e-03 | Time: 229.2s
#       ✓ Val loss improved (2.1258 → 2.1129). Saving...
#    Epoch 013/100 | Train: 2.1229 | Val: 2.1063 | LR: 9.99e-04 | Time: 229.7s
#       ✓ Val loss improved (2.1129 → 2.1063). Saving...
#    Epoch 014/100 | Train: 2.1127 | Val: 2.0932 | LR: 9.97e-04 | Time: 231.4s
#       ✓ Val loss improved (2.1063 → 2.0932). Saving...
#    Epoch 015/100 | Train: 2.1012 | Val: 2.0922 | LR: 9.95e-04 | Time: 229.3s
#       ✓ Val loss improved (2.0932 → 2.0922). Saving...
#    Epoch 016/100 | Train: 2.0922 | Val: 2.0760 | LR: 9.92e-04 | Time: 229.8s
#       ✓ Val loss improved (2.0922 → 2.0760). Saving...
#    Epoch 017/100 | Train: 2.0823 | Val: 2.0704 | LR: 9.89e-04 | Time: 231.0s
#       ✓ Val loss improved (2.0760 → 2.0704). Saving...
#    Epoch 018/100 | Train: 2.0756 | Val: 2.0596 | LR: 9.85e-04 | Time: 232.9s
#       ✓ Val loss improved (2.0704 → 2.0596). Saving...
#    Epoch 019/100 | Train: 2.0689 | Val: 2.0547 | LR: 9.81e-04 | Time: 235.3s
#       ✓ Val loss improved (2.0596 → 2.0547). Saving...
#    Epoch 020/100 | Train: 2.0632 | Val: 2.0512 | LR: 9.76e-04 | Time: 233.2s
#       ✓ Val loss improved (2.0547 → 2.0512). Saving...
#    Epoch 021/100 | Train: 2.0602 | Val: 2.0472 | LR: 9.70e-04 | Time: 234.3s
#       ✓ Val loss improved (2.0512 → 2.0472). Saving...
#    Epoch 022/100 | Train: 2.0545 | Val: 2.0476 | LR: 9.64e-04 | Time: 229.0s
#       EarlyStopping counter: 1/10
#    Epoch 023/100 | Train: 2.0496 | Val: 2.0392 | LR: 9.57e-04 | Time: 230.5s
#       ✓ Val loss improved (2.0472 → 2.0392). Saving...
#    Epoch 024/100 | Train: 2.0465 | Val: 2.0463 | LR: 9.49e-04 | Time: 234.6s
#       EarlyStopping counter: 1/10
#    Epoch 025/100 | Train: 2.0436 | Val: 2.0352 | LR: 9.42e-04 | Time: 233.2s
#       ✓ Val loss improved (2.0392 → 2.0352). Saving...
#    Epoch 026/100 | Train: 2.0403 | Val: 2.0357 | LR: 9.33e-04 | Time: 233.1s
#       EarlyStopping counter: 1/10
#    Epoch 027/100 | Train: 2.0383 | Val: 2.0321 | LR: 9.24e-04 | Time: 235.1s
#       ✓ Val loss improved (2.0352 → 2.0321). Saving...
#    Epoch 028/100 | Train: 2.0350 | Val: 2.0286 | LR: 9.15e-04 | Time: 229.3s
#       ✓ Val loss improved (2.0321 → 2.0286). Saving...
#    Epoch 029/100 | Train: 2.0321 | Val: 2.0264 | LR: 9.05e-04 | Time: 228.9s
#       ✓ Val loss improved (2.0286 → 2.0264). Saving...
#    Epoch 030/100 | Train: 2.0296 | Val: 2.0293 | LR: 8.94e-04 | Time: 228.3s
#       EarlyStopping counter: 1/10
#    Epoch 031/100 | Train: 2.0277 | Val: 2.0228 | LR: 8.83e-04 | Time: 235.3s
#       ✓ Val loss improved (2.0264 → 2.0228). Saving...
#    Epoch 032/100 | Train: 2.0253 | Val: 2.0218 | LR: 8.72e-04 | Time: 237.8s
#       ✓ Val loss improved (2.0228 → 2.0218). Saving...
#    Epoch 033/100 | Train: 2.0236 | Val: 2.0247 | LR: 8.60e-04 | Time: 246.6s
#       EarlyStopping counter: 1/10
#    Epoch 034/100 | Train: 2.0212 | Val: 2.0173 | LR: 8.47e-04 | Time: 229.3s
#       ✓ Val loss improved (2.0218 → 2.0173). Saving...
#    Epoch 035/100 | Train: 2.0196 | Val: 2.0207 | LR: 8.35e-04 | Time: 234.1s
#       EarlyStopping counter: 1/10
#    Epoch 036/100 | Train: 2.0180 | Val: 2.0157 | LR: 8.22e-04 | Time: 253.5s
#       ✓ Val loss improved (2.0173 → 2.0157). Saving...
#    Epoch 037/100 | Train: 2.0159 | Val: 2.0129 | LR: 8.08e-04 | Time: 241.4s
#       ✓ Val loss improved (2.0157 → 2.0129). Saving...
#    Epoch 038/100 | Train: 2.0145 | Val: 2.0140 | LR: 7.94e-04 | Time: 231.3s
#       EarlyStopping counter: 1/10
# ...
#    Epoch 087/100 | Train: 0.9961 | Val: 0.9849 | LR: 5.95e-05 | Time: 1076.1s
#       ✓ Val loss improved (0.9850 → 0.9849). Saving...
#    Epoch 088/100 | Train: 0.9958 | Val: 0.9847 | LR: 5.16e-05 | Time: 1074.0s
#       ✓ Val loss improved (0.9849 → 0.9847). Saving...
#    Epoch 089/100 | Train: 0.9958 | Val: 0.9851 | LR: 4.42e-05 | Time: 1072.2s
#       EarlyStopping counter: 1/10
#    Epoch 090/100 | Train: 0.9958 | Val: 0.9847 | LR: 3.74e-05 | Time: 1067.9s
#       EarlyStopping counter: 2/10
#    Epoch 091/100 | Train: 0.9956 | Val: 0.9846 | LR: 3.11e-05 | Time: 1069.3s
#       ✓ Val loss improved (0.9847 → 0.9846). Saving...
#    Epoch 092/100 | Train: 0.9955 | Val: 0.9845 | LR: 2.54e-05 | Time: 1069.1s
#       ✓ Val loss improved (0.9846 → 0.9845). Saving...
#    Epoch 093/100 | Train: 0.9953 | Val: 0.9844 | LR: 2.03e-05 | Time: 1068.7s
#       ✓ Val loss improved (0.9845 → 0.9844). Saving...
#    Epoch 094/100 | Train: 0.9953 | Val: 0.9844 | LR: 1.58e-05 | Time: 1071.0s
#       EarlyStopping counter: 1/10
#    Epoch 095/100 | Train: 0.9953 | Val: 0.9844 | LR: 1.19e-05 | Time: 1096.2s
#       ✓ Val loss improved (0.9844 → 0.9844). Saving...
#    Epoch 096/100 | Train: 0.9952 | Val: 0.9843 | LR: 8.59e-06 | Time: 1073.1s
#       ✓ Val loss improved (0.9844 → 0.9843). Saving...
#    Epoch 097/100 | Train: 0.9951 | Val: 0.9843 | LR: 5.86e-06 | Time: 1069.4s
#       ✓ Val loss improved (0.9843 → 0.9843). Saving...
#    Epoch 098/100 | Train: 0.9952 | Val: 0.9843 | LR: 3.74e-06 | Time: 1071.7s
#       ✓ Val loss improved (0.9843 → 0.9843). Saving...
#    Epoch 099/100 | Train: 0.9950 | Val: 0.9843 | LR: 2.22e-06 | Time: 1070.1s
#       EarlyStopping counter: 1/10
#    Epoch 100/100 | Train: 0.9951 | Val: 0.9843 | LR: 1.30e-06 | Time: 1069.1s
#       EarlyStopping counter: 2/10
#    💾 Final model saved: ./results_crossplatform_B22_eta0.2/final_model_B22_eta0.2_M40.pth
#
#    📈 Evaluating all decoders...
#
#    ✅ RESULTS M=40 (B22, η=0.2):
#       Bi-LSTM:         61.15%
#       Min. Distance:   33.03%
#       KL Divergence:   33.58%
#       Max. Likelihood: 33.58%
#    📈 Training plot saved: ./results_crossplatform_B22_eta0.2/training_plot_B22_eta0.2_M40.png
#
# ======================================================================
# 🔬 EXPERIMENT FOR COVERAGE M = 50
#    Error Model: B22 (Nanopore MinION Short)
#    Eta: 0.2, Vocab Size: 34
#    Seq Length: 136
# ======================================================================
#    📊 Data: 80,000 train | 20,000 validation
#    🧠 Model: 34 classes, 541,218 parameters
#
#    🏋️ Training Configuration:
#       Epochs: 100, Patience: 10
#       Warmup: 10 epochs
#       LR: 0.001 → 1e-06
#    Epoch 001/100 | Train: 3.4716 | Val: 3.2955 | LR: 1.00e-04 | Time: 1331.4s
#       ✓ Val loss improved (inf → 3.2955). Saving...
#    Epoch 002/100 | Train: 2.8131 | Val: 2.2149 | LR: 1.90e-04 | Time: 1420.2s
#       ✓ Val loss improved (3.2955 → 2.2149). Saving...
#    Epoch 003/100 | Train: 1.8399 | Val: 1.5887 | LR: 2.80e-04 | Time: 1355.1s
#       ✓ Val loss improved (2.2149 → 1.5887). Saving...
#    Epoch 004/100 | Train: 1.5157 | Val: 1.3980 | LR: 3.70e-04 | Time: 1334.8s
#       ✓ Val loss improved (1.5887 → 1.3980). Saving...
#    Epoch 005/100 | Train: 1.3829 | Val: 1.2893 | LR: 4.60e-04 | Time: 1351.3s
#       ✓ Val loss improved (1.3980 → 1.2893). Saving...
#    Epoch 006/100 | Train: 1.2998 | Val: 1.2208 | LR: 5.50e-04 | Time: 1461.8s
#       ✓ Val loss improved (1.2893 → 1.2208). Saving...
#    Epoch 007/100 | Train: 1.2407 | Val: 1.1638 | LR: 6.40e-04 | Time: 1336.5s
#       ✓ Val loss improved (1.2208 → 1.1638). Saving...
#    Epoch 008/100 | Train: 1.1906 | Val: 1.1240 | LR: 7.30e-04 | Time: 1340.6s
#       ✓ Val loss improved (1.1638 → 1.1240). Saving...
#    Epoch 009/100 | Train: 1.1520 | Val: 1.1014 | LR: 8.20e-04 | Time: 1357.4s
#       ✓ Val loss improved (1.1240 → 1.1014). Saving...
#    Epoch 010/100 | Train: 1.1226 | Val: 1.0644 | LR: 9.10e-04 | Time: 1389.4s
#       ✓ Val loss improved (1.1014 → 1.0644). Saving...
#    Epoch 011/100 | Train: 1.0901 | Val: 1.0269 | LR: 1.00e-03 | Time: 1348.2s
#       ✓ Val loss improved (1.0644 → 1.0269). Saving...
#    Epoch 012/100 | Train: 1.0598 | Val: 0.9988 | LR: 1.00e-03 | Time: 1343.0s
#       ✓ Val loss improved (1.0269 → 0.9988). Saving...
#    Epoch 013/100 | Train: 1.0334 | Val: 0.9835 | LR: 9.99e-04 | Time: 1336.2s
#       ✓ Val loss improved (0.9988 → 0.9835). Saving...
#    Epoch 014/100 | Train: 1.0149 | Val: 0.9682 | LR: 9.97e-04 | Time: 1339.5s
#       ✓ Val loss improved (0.9835 → 0.9682). Saving...
#    Epoch 015/100 | Train: 0.9998 | Val: 0.9581 | LR: 9.95e-04 | Time: 1337.0s
#       ✓ Val loss improved (0.9682 → 0.9581). Saving...
#    Epoch 016/100 | Train: 0.9882 | Val: 0.9471 | LR: 9.92e-04 | Time: 1338.8s
#       ✓ Val loss improved (0.9581 → 0.9471). Saving...
#    Epoch 017/100 | Train: 0.9782 | Val: 0.9382 | LR: 9.89e-04 | Time: 1336.4s
#       ✓ Val loss improved (0.9471 → 0.9382). Saving...
#    Epoch 018/100 | Train: 0.9691 | Val: 0.9310 | LR: 9.85e-04 | Time: 1339.7s
#       ✓ Val loss improved (0.9382 → 0.9310). Saving...
#    Epoch 019/100 | Train: 0.9619 | Val: 0.9247 | LR: 9.81e-04 | Time: 1337.8s
#       ✓ Val loss improved (0.9310 → 0.9247). Saving...
#    Epoch 020/100 | Train: 0.9564 | Val: 0.9230 | LR: 9.76e-04 | Time: 1346.8s
#       ✓ Val loss improved (0.9247 → 0.9230). Saving...
#    Epoch 021/100 | Train: 0.9506 | Val: 0.9189 | LR: 9.70e-04 | Time: 1338.6s
#       ✓ Val loss improved (0.9230 → 0.9189). Saving...
#    Epoch 022/100 | Train: 0.9463 | Val: 0.9238 | LR: 9.64e-04 | Time: 1345.7s
#       EarlyStopping counter: 1/10
#    Epoch 023/100 | Train: 0.9418 | Val: 0.9123 | LR: 9.57e-04 | Time: 1342.7s
#       ✓ Val loss improved (0.9189 → 0.9123). Saving...
#    Epoch 024/100 | Train: 0.9377 | Val: 0.9063 | LR: 9.49e-04 | Time: 1342.9s
#       ✓ Val loss improved (0.9123 → 0.9063). Saving...
#    Epoch 025/100 | Train: 0.9340 | Val: 0.9058 | LR: 9.42e-04 | Time: 1348.2s
#       ✓ Val loss improved (0.9063 → 0.9058). Saving...
#    Epoch 026/100 | Train: 0.9304 | Val: 0.9004 | LR: 9.33e-04 | Time: 1347.3s
#       ✓ Val loss improved (0.9058 → 0.9004). Saving...
#    Epoch 027/100 | Train: 0.9269 | Val: 0.8987 | LR: 9.24e-04 | Time: 1340.3s
#       ✓ Val loss improved (0.9004 → 0.8987). Saving...
#    Epoch 028/100 | Train: 0.9239 | Val: 0.8971 | LR: 9.15e-04 | Time: 1340.7s
#       ✓ Val loss improved (0.8987 → 0.8971). Saving...
#    Epoch 029/100 | Train: 0.9214 | Val: 0.8939 | LR: 9.05e-04 | Time: 1342.2s
#       ✓ Val loss improved (0.8971 → 0.8939). Saving...
#    Epoch 030/100 | Train: 0.9191 | Val: 0.8932 | LR: 8.94e-04 | Time: 1341.5s
#       ✓ Val loss improved (0.8939 → 0.8932). Saving...
#    Epoch 031/100 | Train: 0.9161 | Val: 0.8896 | LR: 8.83e-04 | Time: 1363.2s
#       ✓ Val loss improved (0.8932 → 0.8896). Saving...
#    Epoch 032/100 | Train: 0.9135 | Val: 0.8889 | LR: 8.72e-04 | Time: 1405.6s
#       ✓ Val loss improved (0.8896 → 0.8889). Saving...
#    Epoch 033/100 | Train: 0.9121 | Val: 0.8866 | LR: 8.60e-04 | Time: 1439.4s
#       ✓ Val loss improved (0.8889 → 0.8866). Saving...
#    Epoch 034/100 | Train: 0.9097 | Val: 0.8849 | LR: 8.47e-04 | Time: 1378.1s
#       ✓ Val loss improved (0.8866 → 0.8849). Saving...
#    Epoch 035/100 | Train: 0.9085 | Val: 0.8835 | LR: 8.35e-04 | Time: 1335.2s
#       ✓ Val loss improved (0.8849 → 0.8835). Saving...
#    Epoch 036/100 | Train: 0.9066 | Val: 0.8827 | LR: 8.22e-04 | Time: 1333.1s
#       ✓ Val loss improved (0.8835 → 0.8827). Saving...
#    Epoch 037/100 | Train: 0.9039 | Val: 0.8804 | LR: 8.08e-04 | Time: 1370.7s
#       ✓ Val loss improved (0.8827 → 0.8804). Saving...
#    Epoch 038/100 | Train: 0.9029 | Val: 0.8799 | LR: 7.94e-04 | Time: 1380.1s
#       ✓ Val loss improved (0.8804 → 0.8799). Saving...
#    Epoch 039/100 | Train: 0.9006 | Val: 0.8781 | LR: 7.80e-04 | Time: 1330.9s
#       ✓ Val loss improved (0.8799 → 0.8781). Saving...
#    Epoch 040/100 | Train: 0.8997 | Val: 0.8769 | LR: 7.65e-04 | Time: 1331.7s
#       ✓ Val loss improved (0.8781 → 0.8769). Saving...
#    Epoch 041/100 | Train: 0.8985 | Val: 0.8756 | LR: 7.50e-04 | Time: 1331.4s
#       ✓ Val loss improved (0.8769 → 0.8756). Saving...
#    Epoch 042/100 | Train: 0.8968 | Val: 0.8743 | LR: 7.35e-04 | Time: 1335.4s
#       ✓ Val loss improved (0.8756 → 0.8743). Saving...
#    Epoch 043/100 | Train: 0.8955 | Val: 0.8739 | LR: 7.19e-04 | Time: 1331.6s
#       ✓ Val loss improved (0.8743 → 0.8739). Saving...
#    Epoch 044/100 | Train: 0.8944 | Val: 0.8732 | LR: 7.04e-04 | Time: 1333.8s
#       ✓ Val loss improved (0.8739 → 0.8732). Saving...
#    Epoch 045/100 | Train: 0.8934 | Val: 0.8726 | LR: 6.88e-04 | Time: 1334.7s
#       ✓ Val loss improved (0.8732 → 0.8726). Saving...
#    Epoch 046/100 | Train: 0.8915 | Val: 0.8710 | LR: 6.71e-04 | Time: 1337.7s
#       ✓ Val loss improved (0.8726 → 0.8710). Saving...
#    Epoch 047/100 | Train: 0.8903 | Val: 0.8697 | LR: 6.55e-04 | Time: 1333.6s
#       ✓ Val loss improved (0.8710 → 0.8697). Saving...
#    Epoch 048/100 | Train: 0.8896 | Val: 0.8696 | LR: 6.38e-04 | Time: 1350.3s
#       ✓ Val loss improved (0.8697 → 0.8696). Saving...
#    Epoch 049/100 | Train: 0.8884 | Val: 0.8691 | LR: 6.21e-04 | Time: 1336.2s
#       ✓ Val loss improved (0.8696 → 0.8691). Saving...
#    Epoch 050/100 | Train: 0.8873 | Val: 0.8674 | LR: 6.04e-04 | Time: 1378.9s
#       ✓ Val loss improved (0.8691 → 0.8674). Saving...
#    Epoch 051/100 | Train: 0.8862 | Val: 0.8681 | LR: 5.87e-04 | Time: 1333.4s
#       EarlyStopping counter: 1/10
#    Epoch 052/100 | Train: 0.8854 | Val: 0.8676 | LR: 5.70e-04 | Time: 1377.3s
#       EarlyStopping counter: 2/10
#    Epoch 053/100 | Train: 0.8848 | Val: 0.8660 | LR: 5.53e-04 | Time: 1415.1s
#       ✓ Val loss improved (0.8674 → 0.8660). Saving...
#    Epoch 054/100 | Train: 0.8837 | Val: 0.8652 | LR: 5.35e-04 | Time: 1459.1s
#       ✓ Val loss improved (0.8660 → 0.8652). Saving...
#    Epoch 055/100 | Train: 0.8830 | Val: 0.8641 | LR: 5.18e-04 | Time: 1343.4s
#       ✓ Val loss improved (0.8652 → 0.8641). Saving...
#    Epoch 056/100 | Train: 0.8821 | Val: 0.8638 | LR: 5.00e-04 | Time: 1336.9s
#       ✓ Val loss improved (0.8641 → 0.8638). Saving...
#    Epoch 057/100 | Train: 0.8816 | Val: 0.8629 | LR: 4.83e-04 | Time: 1334.4s
#       ✓ Val loss improved (0.8638 → 0.8629). Saving...
#    Epoch 058/100 | Train: 0.8806 | Val: 0.8627 | LR: 4.66e-04 | Time: 1401.2s
#       ✓ Val loss improved (0.8629 → 0.8627). Saving...
#    Epoch 059/100 | Train: 0.8798 | Val: 0.8628 | LR: 4.48e-04 | Time: 1359.8s
#       EarlyStopping counter: 1/10
#    Epoch 060/100 | Train: 0.8791 | Val: 0.8623 | LR: 4.31e-04 | Time: 1399.4s
#       ✓ Val loss improved (0.8627 → 0.8623). Saving...
#    Epoch 061/100 | Train: 0.8785 | Val: 0.8614 | LR: 4.14e-04 | Time: 1333.2s
#       ✓ Val loss improved (0.8623 → 0.8614). Saving...
#    Epoch 062/100 | Train: 0.8781 | Val: 0.8608 | LR: 3.97e-04 | Time: 1332.4s
#       ✓ Val loss improved (0.8614 → 0.8608). Saving...
#    Epoch 063/100 | Train: 0.8770 | Val: 0.8612 | LR: 3.80e-04 | Time: 1335.4s
#       EarlyStopping counter: 1/10
#    Epoch 064/100 | Train: 0.8766 | Val: 0.8592 | LR: 3.63e-04 | Time: 1329.8s
#       ✓ Val loss improved (0.8608 → 0.8592). Saving...
#    Epoch 065/100 | Train: 0.8758 | Val: 0.8606 | LR: 3.46e-04 | Time: 1381.2s
#       EarlyStopping counter: 1/10
#    Epoch 066/100 | Train: 0.8755 | Val: 0.8587 | LR: 3.30e-04 | Time: 1339.6s
#       ✓ Val loss improved (0.8592 → 0.8587). Saving...
#    Epoch 067/100 | Train: 0.8750 | Val: 0.8583 | LR: 3.13e-04 | Time: 1329.7s
#       ✓ Val loss improved (0.8587 → 0.8583). Saving...
#    Epoch 068/100 | Train: 0.8744 | Val: 0.8583 | LR: 2.97e-04 | Time: 1334.4s
#       EarlyStopping counter: 1/10
#    Epoch 069/100 | Train: 0.8740 | Val: 0.8585 | LR: 2.82e-04 | Time: 1338.6s
#       EarlyStopping counter: 2/10
#    Epoch 070/100 | Train: 0.8736 | Val: 0.8571 | LR: 2.66e-04 | Time: 1338.4s
#       ✓ Val loss improved (0.8583 → 0.8571). Saving...
#    Epoch 071/100 | Train: 0.8730 | Val: 0.8568 | LR: 2.51e-04 | Time: 1336.4s
#       ✓ Val loss improved (0.8571 → 0.8568). Saving...
#    Epoch 072/100 | Train: 0.8725 | Val: 0.8567 | LR: 2.36e-04 | Time: 1342.9s
#       ✓ Val loss improved (0.8568 → 0.8567). Saving...
#    Epoch 073/100 | Train: 0.8722 | Val: 0.8564 | LR: 2.21e-04 | Time: 1337.2s
#       ✓ Val loss improved (0.8567 → 0.8564). Saving...
#    Epoch 074/100 | Train: 0.8716 | Val: 0.8561 | LR: 2.07e-04 | Time: 1336.8s
#       ✓ Val loss improved (0.8564 → 0.8561). Saving...
#    Epoch 075/100 | Train: 0.8714 | Val: 0.8561 | LR: 1.93e-04 | Time: 1388.7s
#       EarlyStopping counter: 1/10
#    Epoch 076/100 | Train: 0.8708 | Val: 0.8554 | LR: 1.79e-04 | Time: 1357.4s
#       ✓ Val loss improved (0.8561 → 0.8554). Saving...
#    Epoch 077/100 | Train: 0.8705 | Val: 0.8552 | LR: 1.66e-04 | Time: 1340.0s
#       ✓ Val loss improved (0.8554 → 0.8552). Saving...
#    Epoch 078/100 | Train: 0.8703 | Val: 0.8548 | LR: 1.54e-04 | Time: 1424.2s
#       ✓ Val loss improved (0.8552 → 0.8548). Saving...
#    Epoch 079/100 | Train: 0.8699 | Val: 0.8546 | LR: 1.41e-04 | Time: 1330.3s
#       ✓ Val loss improved (0.8548 → 0.8546). Saving...
#    Epoch 080/100 | Train: 0.8696 | Val: 0.8546 | LR: 1.29e-04 | Time: 1352.7s
#       ✓ Val loss improved (0.8546 → 0.8546). Saving...
#    Epoch 081/100 | Train: 0.8694 | Val: 0.8541 | LR: 1.18e-04 | Time: 1457.1s
#       ✓ Val loss improved (0.8546 → 0.8541). Saving...
#    Epoch 082/100 | Train: 0.8691 | Val: 0.8537 | LR: 1.07e-04 | Time: 1327.6s
#       ✓ Val loss improved (0.8541 → 0.8537). Saving...
#    Epoch 083/100 | Train: 0.8687 | Val: 0.8535 | LR: 9.64e-05 | Time: 1324.5s
#       ✓ Val loss improved (0.8537 → 0.8535). Saving...
#    Epoch 084/100 | Train: 0.8686 | Val: 0.8534 | LR: 8.64e-05 | Time: 1324.8s
#       ✓ Val loss improved (0.8535 → 0.8534). Saving...
#    Epoch 085/100 | Train: 0.8682 | Val: 0.8538 | LR: 7.69e-05 | Time: 1348.7s
#       EarlyStopping counter: 1/10
#    Epoch 086/100 | Train: 0.8682 | Val: 0.8534 | LR: 6.79e-05 | Time: 1328.8s
#       ✓ Val loss improved (0.8534 → 0.8534). Saving...
#    Epoch 087/100 | Train: 0.8678 | Val: 0.8530 | LR: 5.95e-05 | Time: 1326.9s
#       ✓ Val loss improved (0.8534 → 0.8530). Saving...
#    Epoch 088/100 | Train: 0.8675 | Val: 0.8529 | LR: 5.16e-05 | Time: 1334.1s
#       ✓ Val loss improved (0.8530 → 0.8529). Saving...
#    Epoch 089/100 | Train: 0.8675 | Val: 0.8529 | LR: 4.42e-05 | Time: 1334.0s
#       EarlyStopping counter: 1/10
#    Epoch 090/100 | Train: 0.8674 | Val: 0.8527 | LR: 3.74e-05 | Time: 1331.5s
#       ✓ Val loss improved (0.8529 → 0.8527). Saving...
#    Epoch 091/100 | Train: 0.8673 | Val: 0.8526 | LR: 3.11e-05 | Time: 1332.1s
#       ✓ Val loss improved (0.8527 → 0.8526). Saving...
#    Epoch 092/100 | Train: 0.8671 | Val: 0.8526 | LR: 2.54e-05 | Time: 1338.6s
#       EarlyStopping counter: 1/10
#    Epoch 093/100 | Train: 0.8671 | Val: 0.8524 | LR: 2.03e-05 | Time: 1370.9s
#       ✓ Val loss improved (0.8526 → 0.8524). Saving...
#    Epoch 094/100 | Train: 0.8670 | Val: 0.8524 | LR: 1.58e-05 | Time: 1365.0s
#       ✓ Val loss improved (0.8524 → 0.8524). Saving...
#    Epoch 095/100 | Train: 0.8669 | Val: 0.8523 | LR: 1.19e-05 | Time: 1333.4s
#       ✓ Val loss improved (0.8524 → 0.8523). Saving...
#    Epoch 096/100 | Train: 0.8668 | Val: 0.8524 | LR: 8.59e-06 | Time: 1335.0s
#       EarlyStopping counter: 1/10
#    Epoch 097/100 | Train: 0.8668 | Val: 0.8523 | LR: 5.86e-06 | Time: 1302.5s
#       ✓ Val loss improved (0.8523 → 0.8523). Saving...
#    Epoch 098/100 | Train: 0.8668 | Val: 0.8522 | LR: 3.74e-06 | Time: 1291.4s
#       ✓ Val loss improved (0.8523 → 0.8522). Saving...
#    Epoch 099/100 | Train: 0.8667 | Val: 0.8522 | LR: 2.22e-06 | Time: 1291.6s
#       EarlyStopping counter: 1/10
#    Epoch 100/100 | Train: 0.8667 | Val: 0.8522 | LR: 1.30e-06 | Time: 1293.1s
#       ✓ Val loss improved (0.8522 → 0.8522). Saving...
#    💾 Final model saved: ./results_crossplatform_B22_eta0.2/final_model_B22_eta0.2_M50.pth
#
#    📈 Evaluating all decoders...
#
#    ✅ RESULTS M=50 (B22, η=0.2):
#       Bi-LSTM:         66.35%
#       Min. Distance:   34.19%
#       KL Divergence:   34.77%
#       Max. Likelihood: 34.77%
#    📈 Training plot saved: ./results_crossplatform_B22_eta0.2/training_plot_B22_eta0.2_M50.png

# %%
# In[17]:

# =============================================================================
# CELL 17: SAVE FINAL RESULTS & PLOT
# =============================================================================

print("\n" + "="*70)
print("📊 FINAL RESULTS SUMMARY")
print("="*70)

results_json_path = os.path.join(CONFIG['results_dir'], "experiment_results.json")
with open(results_json_path, 'w') as f:
    json.dump(results, f, indent=4)
print(f"💾 Results saved: {results_json_path}")

print(f"\n   Error Model: {CONFIG['error_name']} ({CONFIG['platform']})")
print(f"   Eta: {CONFIG['eta']}, Vocab Size: {CONFIG['vocab_size']}")
print(f"   Seq Length: {CONFIG['seq_length']}")
print(f"   {'M':<8} {'Bi-LSTM':<12} {'Min.Dist':<12} {'KL Div':<12} {'Max.Like':<12}")
print(f"   {'-'*56}")
for i, M in enumerate(results['coverage']):
    print(f"   {M:<8} {results['lstm'][i]:<12.2f} {results['mindist'][i]:<12.2f} "
          f"{results['kl'][i]:<12.2f} {results['ml'][i]:<12.2f}")
print(f"   {'='*56}")

plot_path = os.path.join(CONFIG['results_dir'], "final_comparison_plot.png")
plot_comparison_results(results, plot_path, CONFIG)

print(f"\n✅ All experiments completed!")
print(f"   Error Model: {CONFIG['error_name']} ({CONFIG['platform']})")
print(f"   Eta: {CONFIG['eta']}, Classes: {CONFIG['vocab_size']}")
print(f"   Results directory: {CONFIG['results_dir']}")
# Out:
# ======================================================================
# 📊 FINAL RESULTS SUMMARY
# ======================================================================
# 💾 Results saved: ./results_crossplatform_B22_eta0.2/experiment_results.json
#
#    Error Model: B22 (Nanopore MinION Short)
#    Eta: 0.2, Vocab Size: 34
#    Seq Length: 136
#    M        Bi-LSTM      Min.Dist     KL Div       Max.Like
#    --------------------------------------------------------
#    1        8.33         8.41         8.41         8.41
#    2        13.09        12.00        12.00        12.00
#    3        16.84        14.16        14.16        14.16
#    5        21.61        17.29        16.50        16.50
#    8        28.67        21.31        21.38        21.38
#    10       32.11        22.74        22.40        22.40
#    15       39.52        26.03        25.91        25.91
#    20       45.32        28.27        28.23        28.23
#    25       50.20        29.83        29.93        29.93
#    30       54.36        31.33        31.81        31.81
#    40       61.15        33.03        33.58        33.58
#    50       66.35        34.19        34.77        34.77
#    ========================================================
# 📈 Comparison plot saved: ./results_crossplatform_B22_eta0.2/final_comparison_plot.png
#
# ✅ All experiments completed!
#    Error Model: B22 (Nanopore MinION Short)
#    Eta: 0.2, Classes: 34
#    Results directory: ./results_crossplatform_B22_eta0.2
